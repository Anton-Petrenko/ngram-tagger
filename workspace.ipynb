# %%
import pandas as pd
import numpy as np

# %%
# initial data processing
#   cascading the sentence number down to the sentences below it
#   necessary for dividing into training and testing sets
raw_dataset = pd.read_csv('ner_dataset2.csv', na_filter=False, dtype=str)
raw_dataset['Sentence Start'] = ~(raw_dataset['Sentence #'] == '')
raw_dataset['Sentence #'] = raw_dataset['Sentence #'].str.extract(r'(\d+)', expand=False).ffill().astype('int64')

# %%
# setup for custom start and end delimiters
TUPLE_START_DELIMITER = '<START>'
TUPLE_SEP_DELIMETER = '<SEP>'
TUPLE_END_DELIMETER = '<END>'

def create_tuple_string_for_json(tup):
    return f'{TUPLE_START_DELIMITER + TUPLE_SEP_DELIMETER.join(tup) + TUPLE_END_DELIMETER}'

def create_tuple_from_delimited_string(string):
    return (*string.replace(TUPLE_START_DELIMITER, '').replace(TUPLE_END_DELIMETER, '').split(TUPLE_SEP_DELIMETER),)

# %%
def generate_ngram_model(training_set, gram_size=4):
    # ---------------- STAGE 1: INITIAL COUNTING ----------------

    # index 0 is unigram, 1 is bigram, 2 is trigram, 3 is quadgram, etc...
    # the keys of each dictionary are effectively a path to the occurence
    #   for a unigram, this would be simply the current word
    #   for higher n-grams, this would be the sequence of previous POS with the current word
    # the values of each dictionary are also dictionaries
    #   the key is the observed type
    #   the value is the number of times this POS occurred
    ngram_maps = [{} for n in range(gram_size)]

    previously_seen = []
    for _, row in training_set.iterrows():
        # reset to having seen nothing if new sentence starts
        if row['Sentence Start']:
            previously_seen = []
        
        # unigram
        if row['Word'] not in ngram_maps[0]:
            ngram_maps[0][row['Word']] = { row['POS']: 1 }
        else:
            if row['POS'] in ngram_maps[0][row['Word']]:
                ngram_maps[0][row['Word']][row['POS']] += 1
            else:
                ngram_maps[0][row['Word']][row['POS']] = 1

        # higher n-grams
        for n in range(1, len(ngram_maps)):
            # skip higher grams if not enough previously seen words in this sentence
            if len(previously_seen) < n:
                break

            # unpacks the last n elements into a tuple with word, then check if that pattern has been observed yet
            pattern = (*previously_seen[-n:len(previously_seen)], row['Word'])
            if pattern not in ngram_maps[n]:
                ngram_maps[n][pattern] = { row['POS']: 1 }
            else:
                if row['POS'] in ngram_maps[n][pattern]:
                    ngram_maps[n][pattern][row['POS']] += 1
                else:
                    ngram_maps[n][pattern][row['POS']] = 1

        # store the part of speech
        previously_seen.append(row['POS'])
        previously_seen = previously_seen[-gram_size:]

    # ---------------- STAGE 2: FLATTENING ----------------

    # index 0 is the unanimous map, index 1 is the highest probability map
    ngram_model = [{}, {}]

    # include all gram sizes in same map for model
    for map in ngram_maps:
        # iterate over every key in every gram size, and store it in either the unanimous or non unanimous layer
        for (key, pos_map) in map.items():
            # check if key should be added to the unanimous map or the highest probability map
            ngram_model[0 if len(pos_map) == 1 else 1][key] = max(pos_map, key=pos_map.get)

    return ngram_model

# %%
def test_model(testing_dataset, model, output_log_filename='output_log.txt'):
    max_gram_size = 4
    
    correct_count = 0
    history = []
    prev_sentence = None

    with open(output_log_filename, 'a', encoding='utf-8') as output_file:
        for _, row in testing_dataset.iterrows():
            # clear history if new sentence
            if row['Sentence #'] != prev_sentence:
                history = []

            history.append(row['Word'])
            
            # limit to quadgram
            if len(history) > max_gram_size:
                history = history[len(history)-max_gram_size:]

            answer = None

            # construct n grams
            grams = []
            for gram_index in range(0, max_gram_size):
                if len(history) >= gram_index+1:
                    key = tuple(history[min(len(history), max_gram_size)-gram_index-1:]) if gram_index > 0 else history[len(history)-1]
                    grams.append(key)
            

            # unanimous, in ascending order
            for gram in grams:
                if gram in model[0]:
                    answer = model[0][gram]
                    break
            # ngrams, in descending order
            if answer == None:
                for gram in grams[::-1]:
                    if gram in model[1]:
                        answer = model[1][gram]
                        break
            # failsafe
            if answer == None:
                answer = 'NN'

            history.pop()
            history.append(answer)
            correct_count += 1 if answer == row['POS'] else 0

            print(f'{row['Word']}\t{row['POS']}\t{answer}\t{'MATCH' if answer == row['POS'] else 'MISMATCH'}', file=output_file)

            # update sentence number
            prev_sentence = row['Sentence #']

    accuracy = correct_count / len(testing_dataset)
    return accuracy

# %%
def jackknife_training(raw_dataset, slice_size):
    sentence_count = raw_dataset['Sentence #'].max()

    slice_index = 1

    while slice_index < sentence_count:
        testing_set = raw_dataset[raw_dataset['Sentence #'].between(slice_index, slice_index + slice_size - 1)]
        training_set = raw_dataset[~raw_dataset['Sentence #'].between(slice_index, slice_index + slice_size - 1)]

        print(f"Training on slice ({slice_index}, {slice_index + slice_size - 1})")

        model = generate_ngram_model(training_set)

        accuracy = test_model(testing_set, model)

        print(accuracy)

        slice_index += slice_size

# %%
jackknife_training(raw_dataset, 1000)
# Out:
# Training on slice (1, 1000)
# 0.9540245504371065
# Training on slice (1001, 2000)
# 0.9581074420896993
# Training on slice (2001, 3000)
# 0.9610157039213886
# Training on slice (3001, 4000)
# 0.9571159932119433
# Training on slice (4001, 5000)
# 0.9616279600310261
# Training on slice (5001, 6000)
# 0.958629335562056
# Training on slice (6001, 7000)
# 0.9586132275370813
# Training on slice (7001, 8000)
# 0.9587349115748105
# Training on slice (8001, 9000)
# 0.9594893538574983
# Training on slice (9001, 10000)
# 0.9586474860076785
# Training on slice (10001, 11000)
# 0.9578261067797383
# Training on slice (11001, 12000)
# 0.957850083487522
# Training on slice (12001, 13000)
# 0.9571495109455054
# Training on slice (13001, 14000)
# 0.9598183250683598
# Training on slice (14001, 15000)
# 0.9586616832530284
# Training on slice (15001, 16000)
# 0.958053615679207
# Training on slice (16001, 17000)
# 0.9576536724725832
# Training on slice (17001, 18000)
# 0.9633899220966362
# Training on slice (18001, 19000)
# 0.9562712167232446
# Training on slice (19001, 20000)
# 0.9570020628008251
# Training on slice (20001, 21000)
# 0.9593434935521689
# Training on slice (21001, 22000)
# 0.9562635237788315
# Training on slice (22001, 23000)
# 0.9538823955785086
# Training on slice (23001, 24000)
# 0.9596424951626279
# Training on slice (24001, 25000)
# 0.9579507227929812
# Training on slice (25001, 26000)
# 0.9579213612324672
# Training on slice (26001, 27000)
# 0.9522600534977558
# Training on slice (27001, 28000)
# 0.9607975819912482
# Training on slice (28001, 29000)
# 0.955054110062169
# Training on slice (29001, 30000)
# 0.9555131004366813
# Training on slice (30001, 31000)
# 0.959003325285838
# Training on slice (31001, 32000)
# 0.9561829681914016
# Training on slice (32001, 33000)
# 0.9565987197530303
# Training on slice (33001, 34000)
# 0.9586865895358097
# Training on slice (34001, 35000)
# 0.9557235421166307
# Training on slice (35001, 36000)
# 0.9578304960308356
# Training on slice (36001, 37000)
# 0.9609382130145113
# Training on slice (37001, 38000)
# 0.9569595806318113
# Training on slice (38001, 39000)
# 0.9575389561101934
# Training on slice (39001, 40000)
# 0.9604924660051452
# Training on slice (40001, 41000)
# 0.9553770638107988
# Training on slice (41001, 42000)
# 0.9592705167173252
# Training on slice (42001, 43000)
# 0.957200219018069
# Training on slice (43001, 44000)
# 0.9606791361537386
# Training on slice (44001, 45000)
# 0.9588538522268146
# Training on slice (45001, 46000)
# 0.9533162799196053
# Training on slice (46001, 47000)
# 0.957712814855672
# Training on slice (47001, 48000)
# 0.9571277516101124
