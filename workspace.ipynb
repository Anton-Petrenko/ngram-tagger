# %%
import pandas as pd
import numpy as np

# %%
raw_dataset = pd.read_csv('ner_dataset2.csv')
raw_dataset['Sentence Start'] = ~raw_dataset['Sentence #'].isna()
raw_dataset
# Out:
#           Sentence #           Word  POS Tag  Sentence Start
# 0        Sentence: 1      Thousands  NNS   O            True
# 1                NaN             of   IN   O           False
# 2                NaN  demonstrators  NNS   O           False
# 3                NaN           have  VBP   O           False
# 4                NaN        marched  VBN   O           False
# ...              ...            ...  ...  ..             ...
# 1048570          NaN           they  PRP   O           False
# 1048571          NaN      responded  VBD   O           False
# 1048572          NaN             to   TO   O           False
# 1048573          NaN            the   DT   O           False
# 1048574          NaN         attack   NN   O           False
#
# [1048575 rows x 5 columns]

# %%
# TODO: decide on start and end delimiters
tuple_start_delimiter = '<START>'
tuple_sep_delimiter = '<SEP>'
tuple_end_delimiter = '<END>'

def create_tuple_string_for_json(tup):
    tup_str = f'{tuple_start_delimiter}'
    for i in range(len(tup)):
        tup_str += tup[i]
        if i < len(tup)-1:
            tup_str += '<SEP>'
    tup_str += f'{tuple_end_delimiter}'
    return tup_str

# %%
# # test tuple function
# tup = ('(', '\'', ')')
# create_tuple_string_for_json(tup)

# %%
# index 0 is unigram, 1 is bigram, 2 is trigram, 3 is quadgram
# the keys of each dictionary are effectively a path to the occurence
#   for a unigram, this would be simply the current word
#   for higher n-grams, this would be the sequence of previous POS with the current word
# the values of each dictionary are also dictionaries
#   the key is the observed type
#   the value is the number of times this POS occurred
ngram_maps = [{}, {}, {}, {}]

previously_seen = []
for index, row in raw_dataset.iterrows():
    # reset to having seen nothing if new sentence starts
    if row['Sentence Start']:
        previously_seen = []
    
    # unigram
    if row['Word'] not in ngram_maps[0]:
        ngram_maps[0][row['Word']] = { row['POS']: 1 }
    else:
        if row['POS'] in ngram_maps[0][row['Word']]:
            ngram_maps[0][row['Word']][row['POS']] += 1
        else:
            ngram_maps[0][row['Word']][row['POS']] = 1

    # higher n-grams
    for n in range(1, len(ngram_maps)):
        # skip higher grams if not enough previously seen words in this sentence
        if len(previously_seen) < n:
            break

        # unpacks the last n elements into a tuple with word, then check if that pattern has been observed yet
        pattern = (*previously_seen[-n:len(previously_seen)], row['Word'])
        pattern = create_tuple_string_for_json(pattern)
        if pattern not in ngram_maps[n]:
            ngram_maps[n][pattern] = { row['POS']: 1 }
        else:
            if row['POS'] in ngram_maps[n][pattern]:
                ngram_maps[n][pattern][row['POS']] += 1
            else:
                ngram_maps[n][pattern][row['POS']] = 1

    # store the part of speech
    previously_seen.append(row['POS'])

# %%
ngram_maps
# Out:
# [{'Thousands': {'NNS': 114},
#   'of': {'IN': 26352, 'RP': 2},
#   'demonstrators': {'NNS': 110},
#   'have': {'VBP': 4872, 'VB': 613},
#   'marched': {'VBN': 17, 'VBD': 48},
#   'through': {'IN': 515},
#   'London': {'NNP': 261},
#   'to': {'TO': 23027, 'IN': 139, 'CC': 47},
#   'protest': {'VB': 114, 'NN': 123},
#   'the': {'DT': 52572, 'NNP': 1},
#   'war': {'NN': 720},
#   'in': {'IN': 26315, 'RP': 8},
#   'Iraq': {'NNP': 1738},
#   'and': {'CC': 19936},
#   'demand': {'VB': 45, 'NN': 175},
#   'withdrawal': {'NN': 154},
#   'British': {'JJ': 561, 'NNP': 59, 'NNS': 16, 'NN': 1},
#   'troops': {'NNS': 1195},
#   'from': {'IN': 4539},
#   'that': {'DT': 347, 'IN': 3898, 'WDT': 2055, 'RB': 1},
#   'country': {'NN': 1925},
#   '.': {'.': 47761},
#   'Families': {'NNS': 6},
#   'soldiers': {'NNS': 757},
#   'killed': {'VBN': 1978, 'VBD': 883},
#   'conflict': {'NN': 244, 'VBP': 1},
#   'joined': {'VBD': 91, 'VBN': 25},
#   'protesters': {'NNS': 197},
#   'who': {'WP': 1919},
#   'carried': {'VBD': 101, 'VBN': 121},
#   'banners': {'NNS': 11},
#   'with': {'IN': 5381},
#   'such': {'JJ': 368, 'PDT': 40},
#   'slogans': {'NNS': 36},
#   'as': {'IN': 3693, 'RB': 413},
#   '"': {'``': 3686},
#   'Bush': {'NNP': 976},
#   'Number': {'NN': 1},
#   'One': {'CD': 164, 'NNP': 2},
#   'Terrorist': {'NN': 2, 'NNP': 2},
#   'Stop': {'VB': 1, 'NNP': 2},
#   'Bombings': {'NNS': 3, 'NNPS': 1},
#   'They': {'PRP': 572},
#   'Houses': {'NNS': 2},
#   'Parliament': {'NN': 4, 'NNP': 50},
#   'a': {'DT': 20480, 'NNP': 1},
#   'rally': {'NN': 90, 'VB': 6, 'VBZ': 1},
#   'Hyde': {'NNP': 2},
#   'Park': {'NNP': 20},
#   'Police': {'NNS': 413, 'NN': 16, 'NNP': 41},
#   'put': {'VBD': 57, 'VB': 56, 'VBN': 65, 'VBP': 3, 'NN': 2},
#   'number': {'NN': 458, 'VB': 3},
#   'marchers': {'NNS': 7},
#   'at': {'IN': 4343},
#   '10000': {'CD': 56},
#   'while': {'IN': 562, 'NN': 14},
#   'organizers': {'NNS': 22},
#   'claimed': {'VBD': 146, 'VBN': 135},
#   'it': {'PRP': 3021},
#   'was': {'VBD': 4878},
#   '1,00,000': {'CD': 36},
#   'The': {'DT': 11310, 'NNP': 3},
#   'comes': {'VBZ': 234},
#   'on': {'IN': 6692, 'RP': 18},
#   'eve': {'NN': 22, 'JJ': 1},
#   'annual': {'JJ': 133},
#   'conference': {'NN': 240},
#   'Britain': {'NNP': 335},
#   "'s": {'POS': 10872, 'VBZ': 48, 'PRP': 1, 'NNP': 2},
#   'ruling': {'VBG': 57, 'NN': 196},
#   'Labor': {'NNP': 68, 'NN': 12},
#   'Party': {'NNP': 293, 'NN': 13},
#   'southern': {'JJ': 830},
#   'English': {'JJ': 14, 'NNS': 3, 'NNP': 22},
#   'seaside': {'NN': 3},
#   'resort': {'NN': 66, 'VB': 2},
#   'Brighton': {'NNP': 1},
#   'party': {'NN': 494},
#   'is': {'VBZ': 6746},
#   'divided': {'VBN': 67, 'VBD': 7},
#   'over': {'IN': 1115, 'RP': 141, 'RB': 7},
#   'participation': {'NN': 33},
#   'continued': {'JJ': 55, 'VBD': 85, 'VBN': 30},
#   'deployment': {'NN': 51},
#   '8500': {'CD': 5},
#   'march': {'NN': 25, 'VB': 6, 'VBP': 3},
#   'came': {'VBD': 392},
#   'ahead': {'RB': 248},
#   'anti-war': {'JJ': 13},
#   'protests': {'NNS': 279, 'VBZ': 1},
#   'today': {'NN': 218},
#   'other': {'JJ': 1396, 'NN': 70},
#   'cities': {'NNS': 149},
#   ',': {',': 32753, 'CC': 1},
#   'including': {'VBG': 809, 'IN': 2},
#   'Rome': {'NNP': 43},
#   'Paris': {'NNP': 108},
#   'Madrid': {'NNP': 32},
#   'International': {'NNP': 398, 'JJ': 34, 'NN': 1},
#   'Atomic': {'NNP': 90},
#   'Energy': {'NNP': 133, 'NN': 6},
#   'Agency': {'NNP': 216},
#   'hold': {'VB': 198, 'VBP': 22, 'NN': 30},
#   'second': {'JJ': 418, 'NN': 22, 'RB': 1},
#   'day': {'NN': 557},
#   'talks': {'NNS': 982, 'VBZ': 1},
#   'Vienna': {'NNP': 56},
#   'Wednesday': {'NNP': 1258},
#   'how': {'WRB': 238},
#   'respond': {'VB': 47},
#   'Iran': {'NNP': 1304},
#   'resumption': {'NN': 19},
#   'low-level': {'JJ': 13},
#   'uranium': {'NN': 171},
#   'conversion': {'NN': 20},
#   'this': {'DT': 1450},
#   'week': {'NN': 1315},
#   'restarted': {'VBD': 5, 'VBN': 2},
#   'parts': {'NNS': 163},
#   'process': {'NN': 233, 'VB': 10, 'VBP': 1},
#   'its': {'PRP$': 2650},
#   'Isfahan': {'NNP': 9},
#   'nuclear': {'JJ': 1053, 'NN': 1},
#   'plant': {'NN': 104, 'VB': 5},
#   'Iranian': {'JJ': 379, 'NN': 1},
#   'officials': {'NNS': 2654},
#   'say': {'VBP': 4083, 'VB': 91, 'NN': 4},
#   'they': {'PRP': 1825},
#   'expect': {'VBP': 46, 'VB': 20},
#   'get': {'VB': 157, 'VBP': 12},
#   'access': {'NN': 123, 'VB': 2},
#   'sealed': {'JJ': 2, 'VBN': 10, 'VBD': 6},
#   'sensitive': {'JJ': 30},
#   'after': {'IN': 2605, 'RB': 1},
#   'an': {'DT': 3845},
#   'IAEA': {'NNP': 73},
#   'surveillance': {'NN': 51},
#   'system': {'NN': 264},
#   'begins': {'VBZ': 51},
#   'functioning': {'VBG': 10, 'JJ': 1},
#   'step': {'NN': 67, 'VB': 43},
#   'will': {'MD': 3378, 'NN': 22},
#   'allow': {'VB': 206, 'VBP': 13},
#   'facility': {'NN': 114},
#   'operate': {'VB': 22, 'VBP': 7},
#   'full': {'JJ': 129},
#   'capacity': {'NN': 53},
#   'European': {'NNP': 407, 'JJ': 322},
#   'Union': {'NNP': 591, 'NN': 2},
#   'U.S.': {'NNP': 4128, 'NN': 1},
#   'backing': {'NN': 18, 'VBG': 25},
#   'has': {'VBZ': 7216},
#   'threatened': {'VBN': 96, 'JJ': 4, 'VBD': 58},
#   'refer': {'VB': 24, 'VBP': 2},
#   'U.N.': {'NNP': 848, 'NN': 1},
#   'Security': {'NNP': 415, 'NN': 57},
#   'Council': {'NNP': 389, 'NN': 3},
#   'which': {'WDT': 1631, 'WP': 1},
#   'could': {'MD': 789},
#   'impose': {'VB': 43},
#   'sanctions': {'NNS': 235},
#   'if': {'IN': 622},
#   'finds': {'VBZ': 13},
#   'Tehran': {'NNP': 332, 'JJ': 4, 'NN': 2, 'VB': 2},
#   'violated': {'VBN': 9, 'VBD': 13},
#   'Nuclear': {'NNP': 21, 'JJ': 2},
#   'Non-Proliferation': {'NNP': 18, 'NN': 1},
#   'treaty': {'NN': 62},
#   'new': {'JJ': 1477},
#   'President': {'NNP': 2502, 'NN': 6},
#   'Mahmoud': {'NNP': 235},
#   'Ahmadinejad': {'NNP': 140},
#   'said': {'VBD': 4970, 'VBN': 351},
#   'Tuesday': {'NNP': 1394},
#   'incentives': {'NNS': 43},
#   'aimed': {'VBN': 263, 'VBD': 1},
#   'persuading': {'VBG': 7},
#   'end': {'VB': 169, 'NN': 291, 'VBP': 2},
#   'fuel': {'NN': 213, 'VB': 17},
#   'program': {'NN': 549},
#   'are': {'VBP': 3718},
#   'insult': {'NN': 6, 'VBP': 1},
#   'nation': {'NN': 337},
#   'Two': {'CD': 187, 'NNP': 1},
#   'Germans': {'NNS': 17},
#   'four': {'CD': 739},
#   'Nigerian': {'JJ': 81, 'NN': 1},
#   'oil': {'NN': 1029},
#   'workers': {'NNS': 364},
#   'were': {'VBD': 3519},
#   'kidnapped': {'VBN': 178, 'VBD': 33},
#   'by': {'IN': 4481, 'RP': 1},
#   'armed': {'JJ': 168, 'VBN': 17},
#   'militants': {'NNS': 1036},
#   'during': {'IN': 1103},
#   'raid': {'NN': 136, 'VB': 2, 'VBD': 1},
#   'boat': {'NN': 62},
#   'Nigeria': {'NNP': 183},
#   'oil-rich': {'JJ': 25, 'NN': 7},
#   'Delta': {'NNP': 51, 'NN': 1},
#   'region': {'NN': 852},
#   'An': {'DT': 380},
#   'official': {'NN': 483, 'JJ': 242},
#   'German': {'JJ': 191, 'NNP': 1, 'NN': 3},
#   'firm': {'NN': 75, 'JJ': 12},
#   'Bilfinger': {'NNP': 3},
#   'Berger': {'NNP': 5},
#   'Thomas': {'NNP': 30},
#   'Horbach': {'NNP': 1},
#   'gunmen': {'NNS': 282},
#   'stopped': {'VBD': 47, 'VBN': 31},
#   'supply': {'NN': 70, 'VB': 16, 'VBP': 2},
#   'sailed': {'VBD': 4, 'VBN': 1},
#   'State': {'NNP': 417, 'NN': 26},
#   'Bayelsa': {'NNP': 5},
#   'inspect': {'VB': 13},
#   'offshore': {'JJ': 41, 'RB': 2},
#   'field': {'NN': 55, 'VB': 4},
#   'owned': {'VBN': 29, 'VBD': 4, 'JJ': 1},
#   'Royal-Dutch': {'NNP': 2},
#   'Shell': {'NNP': 30},
#   'works': {'VBZ': 29, 'NNS': 10},
#   'sub-contractor': {'NN': 1},
#   'for': {'IN': 8498},
#   'Militant': {'JJ': 11, 'NNP': 2, 'NN': 3},
#   'groups': {'NNS': 511, 'VBZ': 2},
#   'frequently': {'RB': 40},
#   'attack': {'VBP': 8, 'NN': 927, 'VB': 58},
#   'operations': {'NNS': 269},
#   'Niger': {'NNP': 113},
#   'social': {'JJ': 82},
#   'services': {'NNS': 155},
#   'better': {'JJR': 84, 'RBR': 6, 'RB': 16},
#   'job': {'NN': 76},
#   'opportunities': {'NNS': 24},
#   'multinational': {'JJ': 13},
#   'companies': {'NNS': 220},
#   'Poor': {'JJ': 3, 'NNP': 12},
#   'residents': {'NNS': 178},
#   'often': {'RB': 109},
#   'complain': {'VBP': 9, 'VB': 2},
#   'been': {'VBN': 2892},
#   'cheated': {'VBN': 1},
#   'out': {'IN': 338, 'RP': 717, 'RB': 11},
#   'huge': {'JJ': 77},
#   'riches': {'NNS': 2},
#   'extracted': {'VBN': 6},
#   'their': {'PRP$': 1758},
#   'tribal': {'JJ': 149, 'NN': 13, 'VB': 1},
#   'lands': {'NNS': 18},
#   '-': {':': 657, 'IN': 511, 'LRB': 1, 'RRB': 1, 'NNP': 1, ',': 1},
#   'where': {'WRB': 658},
#   'bulk': {'NN': 14, 'JJ': 1},
#   '2.3': {'CD': 16},
#   'million': {'CD': 876},
#   'barrels': {'NNS': 81},
#   'petroleum': {'NN': 35},
#   'pumped': {'VBN': 3, 'VBD': 1},
#   'daily': {'RB': 15, 'NN': 8, 'JJ': 49},
#   'Suspected': {'JJ': 2, 'VBN': 11, 'NNP': 3},
#   'Islamist': {'JJ': 24, 'NNP': 55, 'NN': 24},
#   'rebels': {'NNS': 680},
#   'fired': {'VBN': 86, 'VBD': 177},
#   'mortar': {'NN': 39, 'JJ': 3},
#   'shells': {'NNS': 17},
#   'palace': {'NN': 15},
#   'used': {'VBN': 261, 'VBD': 99},
#   'Somalia': {'NNP': 269},
#   'interim': {'JJ': 130, 'NNP': 1, 'NN': 2},
#   'Abdullahi': {'NNP': 13},
#   'Yusuf': {'NNP': 16},
#   'Ahmad': {'NNP': 39},
#   'It': {'PRP': 802},
#   'not': {'RB': 2698},
#   'immediately': {'RB': 153},
#   'clear': {'JJ': 183, 'VB': 26, 'VBP': 1},
#   'president': {'NN': 888},
#   'Mogadishu': {'NNP': 96},
#   'when': {'WRB': 1165},
#   'occurred': {'VBD': 192, 'VBN': 6},
#   'or': {'CC': 933},
#   'anyone': {'DT': 53},
#   'hurt': {'VBN': 61, 'VB': 25, 'VBP': 5, 'VBD': 5, 'NN': 1},
#   'Local': {'JJ': 93},
#   'news': {'NN': 636},
#   'reports': {'NNS': 455, 'VBZ': 218, 'VBP': 2},
#   'least': {'JJS': 1475, 'JJ': 7},
#   'five': {'CD': 562},
#   'hit': {'VBD': 163, 'VBN': 105, 'NN': 26, 'VB': 30, 'VBZ': 1, 'VBP': 2},
#   'compound': {'NN': 64},
#   'mortars': {'NNS': 27},
#   'elsewhere': {'RB': 48},
#   'attacks': {'NNS': 1059, 'VBZ': 7},
#   'government': {'NN': 3031},
#   'go': {'VB': 154, 'VBP': 21, 'NN': 4},
#   'reconciliation': {'NN': 46},
#   'more': {'JJR': 1778, 'RBR': 345},
#   'than': {'IN': 1872},
#   '1300': {'CD': 25},
#   'Somali': {'JJ': 148},
#   'elders': {'NNS': 21},
#   'warlords': {'NNS': 23},
#   'politicians': {'NNS': 75},
#   'invited': {'VBN': 23, 'VBD': 12},
#   'Iraqi': {'JJ': 1139, 'NN': 4, 'NNS': 1},
#   'military': {'JJ': 1302, 'NN': 634},
#   'tanks': {'NNS': 27},
#   'arrived': {'VBN': 48, 'VBD': 116},
#   'northern': {'JJ': 528},
#   'city': {'NN': 961},
#   'Mosul': {'NNP': 108},
#   'offensive': {'NN': 141, 'JJ': 13},
#   'against': {'IN': 1250},
#   'al': {'NNP': 17},
#   'Qaida': {'NNP': 10},
#   'fighters': {'NNS': 193},
#   'Officials': {'NNS': 732, 'NNP': 4},
#   'many': {'JJ': 400, 'NN': 87},
#   'Sunni': {'NNP': 196, 'JJ': 7, 'VB': 1},
#   'Arab': {'NNP': 99, 'JJ': 124, 'NN': 1},
#   'Kurdish': {'NNP': 114, 'JJ': 105, 'VB': 3},
#   'bombings': {'NNS': 239},
#   'last': {'JJ': 1682, 'VB': 18, 'RB': 2, 'NN': 3, 'VBP': 1},
#   '34': {'CD': 32},
#   'people': {'NNS': 2687},
#   'wounded': {'VBD': 235, 'VBN': 453, 'JJ': 19},
#   '200': {'CD': 137},
#   'commanders': {'NNS': 41},
#   'explained': {'VBN': 3, 'VBD': 5},
#   'American': {'JJ': 532, 'NNP': 118, 'NN': 17},
#   'forces': {'NNS': 1297},
#   'participate': {'VB': 40, 'VBP': 3},
#   'fled': {'VBN': 53, 'VBD': 101},
#   'successful': {'JJ': 42},
#   'campaigns': {'NNS': 9},
#   'them': {'PRP': 618},
#   'Anbar': {'NNP': 32},
#   'province': {'NN': 915},
#   'Baghdad': {'NNP': 761, 'VB': 2},
#   'provinces': {'NNS': 93},
#   'largest': {'JJS': 266},
#   'north': {'NN': 170, 'RB': 38, 'JJ': 12},
#   'long': {'RB': 89, 'JJ': 91},
#   'stronghold': {'NN': 60},
#   'militant': {'JJ': 331, 'NN': 110},
#   'In': {'IN': 1726},
#   'violence': {'NN': 701},
#   'one': {'CD': 1452, 'NN': 71, 'PRP': 2},
#   'soldier': {'NN': 250},
#   'patrol': {'NN': 118, 'VB': 7, 'JJ': 4, 'VBP': 2},
#   'Sunday': {'NNP': 1215},
#   'Egyptian': {'JJ': 166, 'NN': 1},
#   'police': {'NNS': 709, 'NN': 684, 'VB': 3},
#   'arrested': {'VBN': 455, 'VBD': 9},
#   '16': {'CD': 133},
#   'members': {'NNS': 609},
#   'opposition': {'NN': 517},
#   'Muslim': {'NNP': 286, 'NN': 42, 'JJ': 10},
#   'Brotherhood': {'NNP': 41, 'NN': 1},
#   'prepare': {'VB': 30, 'VBP': 10},
#   'parliamentary': {'JJ': 264},
#   'runoff': {'NN': 43},
#   'elections': {'NNS': 757},
#   'Saturday': {'NNP': 1152},
#   'arrests': {'NNS': 75},
#   'Friday': {'NNP': 1279},
#   'Alexandria': {'NNP': 6},
#   'A': {'DT': 2201, 'NNP': 14},
#   'spokesman': {'NN': 721},
#   'attempt': {'NN': 141, 'VBP': 3, 'VB': 6},
#   'cut': {'VB': 100, 'VBD': 46, 'VBN': 44, 'NN': 19, 'VBP': 3},
#   'off': {'RB': 33, 'IN': 127, 'RP': 337},
#   'supporters': {'NNS': 170},
#   'punishment': {'NN': 13},
#   'winning': {'VBG': 38, 'NN': 4, 'JJ': 1},
#   'seats': {'NNS': 148},
#   'earlier': {'JJR': 83, 'RBR': 366, 'RB': 60},
#   'tripled': {'VBN': 3},
#   'strength': {'NN': 39},
#   'parliament': {'NN': 451},
#   'recent': {'JJ': 548},
#   'raising': {'VBG': 45, 'NN': 3},
#   'total': {'NN': 68, 'VB': 2, 'JJ': 59, 'VBP': 2},
#   '47': {'CD': 13},
#   'voters': {'NNS': 113},
#   'cast': {'VB': 10, 'VBN': 20, 'VBD': 11, 'NN': 9},
#   'ballots': {'NNS': 58},
#   'nine': {'CD': 172},
#   'no': {'DT': 782, 'RB': 39},
#   'candidate': {'NN': 175},
#   'won': {'VBD': 176, 'VBN': 71},
#   'majority': {'NN': 195},
#   'previous': {'JJ': 105},
#   'round': {'NN': 141, 'VBP': 1, 'JJ': 2, 'RP': 1, 'IN': 1},
#   'voting': {'NN': 72, 'VBG': 22},
#   'banned': {'VBN': 68, 'VBD': 22},
#   'political': {'JJ': 708},
#   'but': {'CC': 1763},
#   'endorses': {'VBZ': 3},
#   'so-called': {'JJ': 69},
#   'independent': {'JJ': 161, 'NN': 2},
#   'candidates': {'NNS': 141},
#   'whose': {'WP$': 99},
#   'allegiance': {'NN': 7},
#   'known': {'VBN': 311, 'JJ': 2},
#   'Hardline': {'JJ': 3},
#   'lawmakers': {'NNS': 255},
#   'Pakistan': {'NNP': 881},
#   'North': {'NNP': 542, 'JJ': 133},
#   'West': {'NNP': 347, 'JJ': 25, 'NN': 2},
#   'Frontier': {'NNP': 22},
#   'Province': {'NNP': 32},
#   'pushed': {'VBN': 29, 'VBD': 35},
#   'law': {'NN': 267},
#   'aims': {'VBZ': 19, 'NNS': 3},
#   'ensure': {'VB': 65},
#   'Islamic': {'JJ': 191, 'NNP': 214},
#   'correctness': {'NN': 2},
#   'public': {'JJ': 308, 'NN': 35},
#   'places': {'NNS': 33, 'VBZ': 2},
#   'establishes': {'VBZ': 5},
#   'morality': {'NN': 1},
#   'enforce': {'VB': 14},
#   'decent': {'JJ': 5},
#   'behavior': {'NN': 20},
#   'six-party': {'JJ': 34},
#   'coalition': {'NN': 460},
#   'religious': {'JJ': 145, 'VBZ': 1, 'NN': 1},
#   'based': {'VBN': 140, 'VBD': 10},
#   'parties': {'NNS': 179},
#   'Mutahida': {'NNP': 2},
#   'Majlis-e-Amal': {'NNP': 3},
#   'dominates': {'VBZ': 3},
#   'provincial': {'JJ': 104},
#   'assembly': {'NN': 64},
#   'so': {'IN': 50, 'RB': 216},
#   'bill': {'NN': 148},
#   'easily': {'RB': 41},
#   'passed': {'VBN': 79, 'VBD': 65},
#   'Thursday': {'NNP': 1333},
#   'vote': {'NN': 418, 'VB': 68, 'VBP': 2},
#   '68-34': {'CD': 1},
#   'governor': {'NN': 108},
#   'must': {'MD': 285},
#   'still': {'RB': 377},
#   'sign': {'VB': 58, 'NN': 41},
#   'before': {'IN': 669, 'RB': 13},
#   'becomes': {'VBZ': 11},
#   'seen': {'VBN': 153},
#   'only': {'RB': 374, 'JJ': 88},
#   'formality': {'NN': 3},
#   'proposed': {'JJ': 13, 'VBN': 104, 'VBD': 22},
#   'calls': {'VBZ': 183, 'NNS': 68},
#   'setting': {'VBG': 41},
#   'up': {'RP': 877, 'RB': 120, 'IN': 53},
#   'force': {'NN': 338, 'VB': 34},
#   'make': {'VB': 285, 'VBP': 43, 'VBD': 1},
#   'sure': {'JJ': 30},
#   'adhere': {'VBP': 1, 'VB': 4},
#   'values': {'NNS': 22},
#   'entertainment': {'NN': 7},
#   'outlets': {'NNS': 13},
#   'close': {'RB': 55, 'JJ': 84, 'NN': 34, 'VB': 62},
#   'weekly': {'JJ': 69},
#   'prayers': {'NNS': 41},
#   'Violators': {'NNS': 3},
#   'be': {'VB': 2526},
#   'jailed': {'VBN': 36, 'JJ': 21, 'VBD': 2},
#   'six': {'CD': 450},
#   'months': {'NNS': 434},
#   'denounced': {'VBN': 17, 'VBD': 22},
#   'measure': {'NN': 118, 'VB': 3},
#   'comparing': {'VBG': 5},
#   'draconian': {'JJ': 2},
#   'rule': {'NN': 139, 'VB': 21, 'VBP': 1},
#   'former': {'JJ': 899},
#   'Taleban': {'NNP': 549},
#   'neighboring': {'VBG': 87, 'JJ': 107},
#   'Afghanistan': {'NNP': 1041},
#   'man': {'NN': 354},
#   'dressed': {'VBD': 2, 'VBN': 17},
#   'suicide': {'NN': 411},
#   'bomber': {'NN': 214},
#   'demonstration': {'NN': 40},
#   'publication': {'NN': 15},
#   'cartoons': {'NNS': 46},
#   'depicting': {'VBG': 12},
#   'Islam': {'NNP': 93, 'NN': 2},
#   'Prophet': {'NNP': 44, 'NN': 1},
#   'Muhammad': {'NNP': 46, 'NN': 1},
#   'Bedfordshire': {'NNP': 1},
#   'Omar': {'NNP': 65},
#   'Khayam': {'NNP': 3},
#   'Bedford': {'NNP': 1},
#   'breaching': {'VBG': 2},
#   'conditions': {'NNS': 134},
#   'his': {'PRP$': 3308},
#   'parole': {'NN': 5},
#   'Home': {'NNP': 21, 'NN': 2},
#   'Office': {'NNP': 41, 'NN': 2},
#   'sought': {'VBD': 33, 'VBN': 32},
#   'investigation': {'NN': 243},
#   'he': {'PRP': 2734},
#   'photographed': {'VBN': 3, 'VBD': 3},
#   'fatigues': {'NNS': 1},
#   'black': {'JJ': 54},
#   'cap': {'NN': 3},
#   'bulky': {'JJ': 2},
#   'belt': {'NN': 10},
#   'told': {'VBD': 637, 'VBN': 48},
#   'Associated': {'NNP': 110},
#   'Press': {'NNP': 125, 'NN': 1},
#   'paroled': {'JJ': 1},
#   'offender': {'NN': 1},
#   'gives': {'VBZ': 39},
#   'cause': {'NN': 65, 'VBZ': 1, 'VB': 43, 'VBP': 4},
#   'concern': {'NN': 149, 'VB': 2},
#   'can': {'MD': 506, 'NN': 2},
#   'sent': {'VBN': 152, 'VBD': 56},
#   'back': {'RB': 188, 'NN': 12, 'VB': 24, 'RP': 30, 'VBP': 4, 'JJ': 15},
#   'prison': {'NN': 303},
#   'AP': {'NNP': 11},
#   'also': {'RB': 2146},
#   'since': {'IN': 1263, 'RB': 2},
#   'year': {'NN': 1493},
#   'serving': {'VBG': 46},
#   'half': {'PDT': 34, 'NN': 129, 'JJ': 10, 'DT': 3},
#   'six-year': {'JJ': 17},
#   'sentence': {'NN': 69},
#   'drug': {'NN': 197},
#   'dealing': {'NN': 1, 'VBG': 34},
#   'Pakistani': {'JJ': 473, 'NNS': 1},
#   'unidentified': {'JJ': 68},
#   'three': {'CD': 1144},
#   'minister': {'NN': 587},
#   'semi-autonomous': {'JJ': 17},
#   'bordering': {'VBG': 41},
#   'prominent': {'JJ': 63},
#   'leader': {'NN': 869},
#   'Malik': {'NNP': 8},
#   'Faridullah': {'NNP': 1},
#   'Khan': {'NNP': 77},
#   'traveling': {'VBG': 99},
#   'South': {'NNP': 552, 'JJ': 169, 'NN': 1},
#   'Waziristan': {'NNP': 82},
#   'vehicle': {'NN': 189},
#   'ambushed': {'VBN': 18, 'VBD': 37},
#   'Kani': {'NNP': 1},
#   'Wam': {'NNP': 1},
#   'area': {'NN': 490},
#   'His': {'PRP$': 161},
#   'driver': {'NN': 80},
#   'elder': {'NN': 13},
#   'No': {'DT': 161, 'NNP': 2},
#   'responsibility': {'NN': 258},
#   'killings': {'NNS': 86},
#   'ambush': {'NN': 33, 'JJ': 11, 'VB': 1},
#   'commander': {'NN': 169, 'VBP': 1},
#   'army': {'NN': 331},
#   'almost': {'RB': 138},
#   'completely': {'RB': 30},
#   'eliminated': {'VBN': 12, 'VBD': 5},
#   'became': {'VBD': 180},
#   'refuge': {'NN': 21},
#   'al-Qaida': {'NNP': 398},
#   'ousted': {'VBN': 44, 'JJ': 57, 'VBD': 44},
#   '2001': {'CD': 233},
#   'senior': {'JJ': 218},
#   'says': {'VBZ': 4640},
#   'wants': {'VBZ': 161},
#   'what': {'WP': 552, 'WDT': 2},
#   'sordid': {'JJ': 1},
#   'chapter': {'NN': 3},
#   'proliferation': {'NN': 11},
#   'top': {'JJ': 459, 'VBP': 3, 'NN': 16, 'VB': 7},
#   'scientists': {'NNS': 64},
#   'behind': {'IN': 112, 'RB': 4, 'NN': 1, 'RP': 1},
#   'build': {'VB': 144, 'VBP': 3},
#   'civilian': {'JJ': 183, 'NN': 2},
#   'ties': {'NNS': 180},
#   'United': {'NNP': 2019, 'VBN': 1},
#   'States': {'NNPS': 1309, 'NNP': 65},
#   'But': {'CC': 756, 'IN': 1},
#   'ready': {'JJ': 110},
#   'scientist': {'NN': 21},
#   'Abdul': {'NNP': 59},
#   'Qadeer': {'NNP': 8},
#   'available': {'JJ': 55},
#   'direct': {'JJ': 75, 'VB': 6},
#   'questioning': {'VBG': 38},
#   'sale': {'NN': 54},
#   'secrets': {'NNS': 13},
#   'states': {'NNS': 142, 'VBZ': 2},
#   'Libya': {'NNP': 38},
#   'Korea': {'NNP': 514},
#   'He': {'PRP': 1636},
#   'there': {'EX': 432, 'RB': 159},
#   'reasons': {'NNS': 38},
#   'national': {'JJ': 351, 'NN': 23},
#   'sensitivities': {'NNS': 3},
#   'making': {'VBG': 169},
#   'him': {'PRP': 676},
#   'giving': {'VBG': 79},
#   'background': {'NN': 8},
#   'briefing': {'NN': 12},
#   'small': {'JJ': 234},
#   'group': {'NN': 1235},
#   'reporters': {'NNS': 281},
#   'Washington': {'NNP': 544},
#   'admitted': {'VBD': 13, 'VBN': 40},
#   '2004': {'CD': 241},
#   'operated': {'VBD': 10, 'VBN': 24},
#   'worldwide': {'JJ': 69, 'NN': 31, 'VBP': 2, 'VBD': 1},
#   'clandestine': {'NN': 1, 'JJ': 8},
#   'network': {'NN': 136},
#   'sell': {'VB': 43, 'VBP': 9},
#   'technology': {'NN': 95},
#   'market': {'NN': 226, 'VB': 2},
#   'placed': {'VBN': 47, 'VBD': 21},
#   'under': {'IN': 665},
#   'house': {'NN': 204, 'VB': 6},
#   'arrest': {'NN': 183, 'VB': 21},
#   'Islamabad': {'NNP': 112, 'VBN': 1},
#   'because': {'IN': 607},
#   'considered': {'VBN': 73, 'VBD': 11},
#   'father': {'NN': 70},
#   'bomb': {'NN': 679, 'VB': 12},
#   'Army': {'NNP': 176, 'NN': 8},
#   'renew': {'VB': 22},
#   'controversial': {'JJ': 107},
#   'multi-billion': {'JJ': 4},
#   'dollar': {'NN': 96},
#   'contract': {'NN': 53, 'VB': 4},
#   'Halliburton': {'NNP': 5},
#   'company': {'NN': 396},
#   'provide': {'VB': 162, 'VBP': 11},
#   'logistical': {'JJ': 19},
#   'support': {'NN': 343, 'VB': 98, 'VBP': 25},
#   'providing': {'VBG': 76},
#   'list': {'NN': 112, 'VB': 1},
#   'meals': {'NNS': 6},
#   'communication': {'NN': 18},
#   'several': {'JJ': 784, 'NN': 15},
#   'years': {'NNS': 1013},
#   'Critics': {'NNS': 45},
#   'include': {'VBP': 189, 'VB': 80},
#   'auditors': {'NNS': 4},
#   'congressional': {'JJ': 40},
#   'Democrats': {'NNS': 24, 'NNPS': 83},
#   'produced': {'VBN': 31, 'VBD': 13},
#   'some': {'DT': 873},
#   'shoddy': {'JJ': 3},
#   'work': {'NN': 209, 'VB': 134, 'VBP': 16},
#   'charges': {'VBZ': 9, 'NNS': 435},
#   'too': {'RB': 100},
#   'much': {'JJ': 61, 'RB': 69, 'NN': 86},
#   'money': {'NN': 212},
#   'strongly': {'RB': 62},
#   'denies': {'VBZ': 116},
#   'allegations': {'NNS': 163},
#   'When': {'WRB': 64},
#   're-bidding': {'NN': 1},
#   'chance': {'NN': 50},
#   'compete': {'VB': 26, 'VBP': 4},
#   'portions': {'NNS': 15},
#   'Representatives': {'NNS': 21, 'NNPS': 26, 'NNP': 22},
#   'Asia': {'NNP': 217, 'NN': 2},
#   'Pacific': {'NNP': 66, 'JJ': 1},
#   'Economic': {'NNP': 57, 'JJ': 27},
#   'Cooperation': {'NNP': 43},
#   'Business': {'NNP': 7, 'NN': 5},
#   'Advisory': {'NNP': 3},
#   'holding': {'VBG': 142, 'NN': 4},
#   'meetings': {'NNS': 83},
#   'finalize': {'VB': 8},
#   'report': {'NN': 732, 'VBP': 33, 'VB': 38},
#   'APEC': {'NNP': 18},
#   'leaders': {'NNS': 679},
#   'summit': {'NN': 229},
#   'September': {'NNP': 315},
#   '8': {'CD': 80},
#   '9': {'CD': 84},
#   'VOA': {'NNP': 237},
#   'Nancy-Amelia': {'NNP': 1},
#   'Collins': {'NNP': 4},
#   'Sydney': {'NNP': 21},
#   'security': {'NN': 1148},
#   'climate': {'NN': 55},
#   'change': {'NN': 97, 'VB': 56, 'VBP': 1},
#   'World': {'NNP': 590, 'NN': 8},
#   'Trade': {'NNP': 93, 'NN': 1},
#   'Organization': {'NNP': 275},
#   'stalled': {'VBN': 41, 'VBD': 3},
#   'negotiations': {'NNS': 163},
#   'investment': {'NN': 154},
#   'all': {'DT': 618, 'PDT': 70, 'RB': 4, 'NN': 1},
#   'expected': {'VBN': 584, 'VBD': 11, 'JJ': 2},
#   'among': {'IN': 391},
#   'major': {'JJ': 376},
#   'topics': {'NNS': 14},
#   'ABAC': {'NNP': 7},
#   'Tim': {'NNP': 9},
#   'Harcourt': {'NNP': 10},
#   'chief': {'JJ': 75, 'NN': 345},
#   'economist': {'NN': 16},
#   'Australian': {'NNP': 8, 'JJ': 105, 'NN': 6},
#   'Commission': {'NNP': 105, 'NN': 2},
#   'plays': {'VBZ': 11, 'NNS': 2},
#   'important': {'JJ': 125},
#   'role': {'NN': 188},
#   'informing': {'VBG': 4},
#   'governments': {'NNS': 124},
#   'problems': {'NNS': 177},
#   'most': {'RBS': 289, 'JJS': 256},
#   'thing': {'NN': 11},
#   'business': {'NN': 163},
#   'do': {'VB': 148, 'VBP': 125},
#   'tell': {'VB': 18, 'VBP': 11},
#   'logjams': {'NNS': 1},
#   'obstacles': {'NNS': 13},
#   'things': {'NNS': 23},
#   'improve': {'VB': 90, 'VBP': 2},
#   'I': {'PRP': 150, 'NNP': 35},
#   'think': {'VBP': 12, 'VB': 8, 'NN': 3},
#   'actually': {'RB': 19},
#   'played': {'VBN': 28, 'VBD': 36},
#   'pretty': {'RB': 4},
#   'good': {'JJ': 119, 'NN': 3},
#   'leadership': {'NN': 79},
#   'talking': {'VBG': 10},
#   'about': {'IN': 1396, 'RB': 82},
#   'trade': {'NN': 325, 'VB': 7},
#   'facilitation': {'NN': 2},
#   'basically': {'RB': 1},
#   'standards': {'NNS': 50},
#   'consistent': {'JJ': 9},
#   'harmonious': {'JJ': 3},
#   'across': {'IN': 315},
#   'comprises': {'VBZ': 8},
#   'private': {'JJ': 138},
#   'sector': {'NN': 207},
#   'each': {'DT': 221},
#   '21': {'CD': 101},
#   'economies': {'NNS': 42},
#   'meets': {'VBZ': 28},
#   'times': {'NNS': 76},
#   'made': {'VBN': 294, 'VBD': 363},
#   'permanent': {'JJ': 77},
#   'body': {'NN': 151},
#   '1995': {'CD': 89},
#   'perspective': {'NN': 4},
#   'within': {'IN': 203},
#   'Members': {'NNS': 44},
#   'represent': {'VBP': 16, 'VB': 10},
#   'range': {'NN': 55, 'VBP': 3, 'VB': 2},
#   'sectors': {'NNS': 65},
#   'medium': {'JJ': 7, 'NN': 1},
#   'businesses': {'NNS': 75},
#   'need': {'NN': 67, 'VBP': 47, 'VB': 33},
#   'energy': {'NN': 271},
#   'efficiency': {'NN': 11},
#   'encourage': {'VB': 39, 'VBP': 2},
#   'conservation': {'NN': 10},
#   'practices': {'NNS': 19, 'VBZ': 1},
#   'discuss': {'VB': 268},
#   'ways': {'NNS': 79},
#   'enhance': {'VB': 11},
#   'regional': {'JJ': 171},
#   'cooperation': {'NN': 143},
#   'reckon': {'VBP': 1},
#   "'ll": {'MD': 9},
#   'talk': {'VB': 25, 'NN': 6, 'VBP': 1},
#   'little': {'JJ': 61, 'RB': 25, 'NN': 3},
#   'bit': {'NN': 15, 'RB': 2, 'VBD': 1},
#   'customs': {'NNS': 35},
#   'quarantine': {'NN': 8, 'VB': 1},
#   'having': {'VBG': 99},
#   'arrangements': {'NNS': 9},
#   'around': {'IN': 291, 'RP': 3, 'RB': 7},
#   'And': {'CC': 178, 'NNP': 2},
#   'want': {'VB': 33, 'VBP': 133},
#   'one-stop': {'JJ': 1},
#   'shop': {'NN': 14},
#   'terms': {'NNS': 64},
#   'combining': {'VBG': 3},
#   'immigration': {'NN': 57},
#   'together': {'RB': 107},
#   '�': {',': 3, ':': 2, ';': 8, '``': 8},
#   'just': {'RB': 300},
#   'streamlined': {'JJ': 1},
#   'provides': {'VBZ': 47},
#   'certainty': {'NN': 2},
#   'non-governmental': {'JJ': 20},
#   'formal': {'JJ': 63},
#   'dialogue': {'NN': 66},
#   'present': {'VB': 27, 'JJ': 36, 'NN': 4, 'VBP': 1},
#   'meeting': {'NN': 470, 'VBG': 122},
#   'Sudan': {'NNP': 367, 'JJ': 1, 'VB': 1, 'NN': 1},
#   'order': {'VB': 6, 'NN': 159},
#   'Darfur': {'NNP': 328, 'NN': 1, 'VB': 2},
#   'asking': {'VBG': 46, 'NN': 1},
#   'same': {'NN': 8, 'JJ': 218},
#   'Foreign': {'NNP': 351, 'JJ': 33, 'NN': 2},
#   'Minister': {'NNP': 1220, 'NN': 59},
#   'Mustafa': {'NNP': 12},
#   'Osman': {'NNP': 15},
#   'Ismail': {'NNP': 37},
#   'Sudanese': {'JJ': 139, 'NNS': 7, 'NN': 2},
#   'withdraw': {'VB': 92},
#   'positions': {'NNS': 66},
#   'held': {'VBN': 426, 'VBD': 133, 'JJ': 3},
#   'April': {'NNP': 191},
#   'cease-fire': {'NN': 87},
#   'western': {'JJ': 330},
#   'agree': {'VBP': 11, 'VB': 63},
#   'stop': {'VB': 248, 'VBP': 6, 'NN': 37},
#   'Mr.': {'NNP': 3086},
#   'announced': {'VBD': 303, 'VBN': 190, 'JJ': 2},
#   'decision': {'NN': 263},
#   'Nations': {'NNPS': 213, 'NNP': 384},
#   'African': {'NNP': 181, 'JJ': 258},
#   'Khartoum': {'NNP': 52},
#   'weeks': {'NNS': 334},
#   'AU': {'NNP': 67},
#   'repeatedly': {'RB': 86},
#   'truce': {'NN': 67},
#   'head': {'NN': 285, 'VB': 30, 'VBP': 1},
#   'accused': {'VBD': 136, 'VBN': 353, 'NN': 1},
#   'helicopters': {'NNS': 68},
#   'bombing': {'VBG': 84, 'NN': 133},
#   'rebel': {'NN': 220, 'JJ': 66},
#   'sites': {'NNS': 65},
#   'village': {'NN': 159},
#   'Labado': {'NNP': 3},
#   'defending': {'VBG': 19},
#   'Aid': {'NN': 4, 'JJ': 15, 'NNP': 5},
#   'relief': {'NN': 184},
#   'efforts': {'NNS': 417},
#   'suspended': {'VBN': 64, 'VBD': 44, 'JJ': 8},
#   'due': {'JJ': 203, 'RB': 5},
#   'Indonesian': {'JJ': 112, 'NN': 2},
#   'men': {'NNS': 501},
#   'connection': {'NN': 114},
#   'October': {'NNP': 246},
#   '1': {'CD': 138},
#   'Bali': {'NNP': 34},
#   'left': {'VBD': 197, 'VBN': 112, 'NN': 7, 'JJ': 5},
#   '23': {'CD': 77},
#   'dead': {'JJ': 280, 'RB': 14, 'NN': 65},
#   'flown': {'VBN': 23},
#   'Java': {'NNP': 26},
#   'island': {'NN': 271},
#   'headquarters': {'NN': 78, 'NNS': 3},
#   'French': {'JJ': 361, 'NNS': 20, 'NNP': 33},
#   'agencies': {'NNS': 117},
#   '(': {'LRB': 664},
#   'Cholily': {'NNP': 1},
#   ')': {'RRB': 665},
#   'captured': {'VBN': 122, 'VBD': 68},
#   'series': {'NN': 259, 'NNS': 1},
#   'counter-terrorism': {'NN': 23},
#   'raids': {'NNS': 95},
#   'Indonesia': {'NNP': 219},
#   'ended': {'VBD': 142, 'VBN': 48},
#   'death': {'NN': 493},
#   'alleged': {'JJ': 199, 'VBD': 21, 'VBN': 29},
#   'extremist': {'NN': 39, 'VB': 1},
#   'bombmaker': {'NN': 4},
#   'Azahari': {'NNP': 8},
#   'bin': {'NNP': 91},
#   'Husin': {'NNP': 7},
#   'authorities': {'NNS': 760},
#   'blame': {'VBP': 28, 'VB': 14, 'NN': 3},
#   'orchestrating': {'VBG': 2},
#   'month': {'NN': 1047},
#   'well': {'RB': 303, 'NN': 2},
#   '2002': {'CD': 186},
#   'Gunmen': {'NNS': 31},
#   'shot': {'VBN': 159, 'VBD': 95, 'NN': 5},
#   'Roman': {'NNP': 52, 'JJ': 2},
#   'Catholic': {'NNP': 60, 'JJ': 13},
#   'nun': {'NN': 5},
#   'her': {'PRP$': 489, 'PRP': 93},
#   'bodyguard': {'NN': 17},
#   'hospital': {'NN': 220},
#   'she': {'PRP': 342},
#   'worked': {'VBD': 53, 'VBN': 21},
#   'Islamist-controlled': {'JJ': 1},
#   'Some': {'DT': 230},
#   'witnesses': {'NNS': 66},
#   'shooting': {'NN': 68, 'VBG': 23},
#   'feared': {'VBD': 17, 'VBN': 14},
#   'linked': {'VBN': 120, 'VBD': 6},
#   'anger': {'NN': 23, 'VB': 1},
#   'toward': {'IN': 153},
#   'Pope': {'NNP': 111, 'NN': 3},
#   'Benedict': {'NNP': 71},
#   'pistols': {'NNS': 2},
#   'attacked': {'VBD': 151, 'VBN': 65},
#   'Sister': {'NNP': 1},
#   'Leonella': {'NNP': 1},
#   'Sgorbati': {'NNP': 1},
#   'finished': {'VBD': 43, 'VBN': 10},
#   'teaching': {'VBG': 5, 'NN': 1},
#   'medical': {'JJ': 155},
#   'school': {'NN': 122},
#   'class': {'NN': 22},
#   'suspect': {'NN': 88, 'VBP': 48, 'JJ': 9, 'VB': 2},
#   'Vatican': {'NNP': 87},
#   'deplored': {'VBD': 4},
#   'hoped': {'VBD': 15, 'VBN': 11},
#   'isolated': {'JJ': 13, 'VBN': 7, 'VBD': 1},
#   'event': {'NN': 103},
#   'irrationality': {'JJ': 1},
#   'arising': {'VBG': 3},
#   'comments': {'NNS': 176},
#   'angered': {'VBD': 17, 'VBN': 13},
#   'Muslims': {'NNS': 47, 'NNPS': 107, 'NNP': 7},
#   'Authorities': {'NNS': 428},
#   'determined': {'VBN': 34, 'JJ': 1, 'VBD': 6},
#   'motive': {'NN': 22},
#   'pope': {'NN': 96},
#   'meant': {'VBD': 7, 'VBN': 42},
#   'offense': {'NN': 8},
#   'quoted': {'VBD': 46, 'VBN': 50},
#   '14': {'CD': 166},
#   'century': {'NN': 153},
#   'Byzantine': {'NNP': 1, 'NN': 2},
#   'emperor': {'NN': 8},
#   'saying': {'VBG': 784, 'NN': 1},
#   'teachings': {'NNS': 6},
#   'Muhammed': {'NNP': 3},
#   'brought': {'VBD': 58, 'VBN': 63},
#   'evil': {'NN': 6, 'JJ': 5},
#   'world': {'NN': 742},
#   'targeted': {'VBN': 43, 'VBD': 53, 'JJ': 14},
#   'northwest': {'NN': 37, 'JJS': 31, 'JJ': 33, 'VB': 1, 'NNP': 1, 'RB': 2},
#   'third': {'JJ': 220, 'NN': 38},
#   'launching': {'VBG': 35, 'NN': 4},
#   'airstrikes': {'NNS': 34, 'VBZ': 1},
#   'suspected': {'JJ': 380, 'VBN': 138, 'VBD': 5},
#   'insurgents': {'NNS': 500},
#   'Helicopter': {'NN': 1},
#   'gunships': {'NNS': 18},
#   'pounded': {'VBD': 10, 'VBN': 5},
#   'hideouts': {'NNS': 16},
#   'Orakzai': {'NNP': 19},
#   'Taliban': {'NNP': 263},
#   'believed': {'VBN': 158, 'VBD': 17},
#   'avoid': {'VB': 81},
#   'nearby': {'JJ': 92, 'RB': 12},
#   'launched': {'VBD': 91, 'VBN': 103},
#   'hunt': {'VB': 17, 'NN': 9},
#   'So': {'RB': 35, 'IN': 7},
#   'far': {'RB': 161, 'JJ': 2},
#   'nearly': {'RB': 459},
#   '100': {'CD': 197},
#   'reported': {'VBN': 299, 'VBD': 174, 'JJ': 13},
#   'On': {'IN': 401, 'NNP': 1},
#   'dozens': {'NNS': 95},
#   'stormed': {'VBD': 45, 'VBN': 2},
#   'checkpoint': {'NN': 79},
#   'At': {'IN': 348},
#   '32': {'CD': 43},
#   'counter-attack': {'NN': 2, 'JJ': 1},
#   'Elsewhere': {'RB': 83},
#   'found': {'VBD': 185, 'VBN': 287, 'VB': 1},
#   'bodies': {'NNS': 167},
#   'had': {'VBD': 1463, 'VBN': 55},
#   'Kurram': {'NNP': 7},
#   'along': {'IN': 303, 'RP': 2, 'RB': 1},
#   'Afghan': {'JJ': 810, 'NN': 4},
#   'border': {'NN': 609, 'VBP': 1, 'VB': 1, 'VBZ': 1},
#   'few': {'JJ': 141},
#   'days': {'NNS': 525},
#   'ago': {'RB': 323, 'IN': 20},
#   'separate': {'JJ': 275, 'VB': 5},
#   'clashes': {'NNS': 130, 'VBZ': 2},
#   '13': {'CD': 164},
#   'guerrillas': {'NNS': 44},
#   'two': {'CD': 2614},
#   'encounters': {'NNS': 2},
#   'central': {'JJ': 317},
#   'Uruzgan': {'NNP': 37},
#   'others': {'NNS': 613},
#   'injured': {'VBN': 170, 'VBD': 24, 'JJ': 22, 'NN': 21},
#   'fighting': {'NN': 246, 'VBG': 318},
#   'Another': {'DT': 91},
#   'eastern': {'JJ': 367},
#   'Paktika': {'NNP': 21},
#   'Separately': {'RB': 88},
#   'NATO-led': {'JJ': 42},
#   'peacekeeping': {'NN': 80, 'VBG': 42, 'JJ': 1},
#   'mission': {'NN': 236},
#   'early': {'JJ': 344, 'RB': 125},
#   'Mazar-e-Sharif': {'NNP': 2},
#   'motivated': {'VBN': 7, 'JJ': 21},
#   'spared': {'VBN': 3, 'VBD': 1},
#   'bloodshed': {'NN': 13},
#   'plagued': {'VBN': 23, 'VBD': 1},
#   ...},
#  {'<START>NNS<SEP>of<END>': {'IN': 5682},
#   '<START>IN<SEP>demonstrators<END>': {'NNS': 23},
#   '<START>NNS<SEP>have<END>': {'VBP': 2991},
#   '<START>VBP<SEP>marched<END>': {'VBN': 17, 'VBD': 1},
#   '<START>VBN<SEP>through<END>': {'IN': 60},
#   '<START>IN<SEP>London<END>': {'NNP': 151},
#   '<START>NNP<SEP>to<END>': {'TO': 1930, 'IN': 3},
#   '<START>TO<SEP>protest<END>': {'VB': 107},
#   '<START>VB<SEP>the<END>': {'DT': 3611},
#   '<START>DT<SEP>war<END>': {'NN': 169},
#   '<START>NN<SEP>in<END>': {'IN': 8917},
#   '<START>IN<SEP>Iraq<END>': {'NNP': 1151},
#   '<START>NNP<SEP>and<END>': {'CC': 4511},
#   '<START>CC<SEP>demand<END>': {'VB': 1, 'NN': 6},
#   '<START>DT<SEP>withdrawal<END>': {'NN': 63},
#   '<START>NN<SEP>of<END>': {'IN': 15434},
#   '<START>IN<SEP>British<END>': {'JJ': 84, 'NNP': 10},
#   '<START>JJ<SEP>troops<END>': {'NNS': 466},
#   '<START>NNS<SEP>from<END>': {'IN': 1412},
#   '<START>IN<SEP>that<END>': {'DT': 167, 'IN': 5},
#   '<START>DT<SEP>country<END>': {'NN': 1509},
#   '<START>NN<SEP>.<END>': {'.': 18704},
#   '<START>IN<SEP>soldiers<END>': {'NNS': 43},
#   '<START>NNS<SEP>killed<END>': {'VBN': 76, 'VBD': 229},
#   '<START>VBN<SEP>in<END>': {'IN': 3187, 'RP': 3},
#   '<START>IN<SEP>the<END>': {'DT': 27754},
#   '<START>DT<SEP>conflict<END>': {'NN': 101},
#   '<START>NN<SEP>joined<END>': {'VBD': 10},
#   '<START>VBD<SEP>the<END>': {'DT': 4978},
#   '<START>DT<SEP>protesters<END>': {'NNS': 54},
#   '<START>NNS<SEP>who<END>': {'WP': 615},
#   '<START>WP<SEP>carried<END>': {'VBD': 7},
#   '<START>VBD<SEP>banners<END>': {'NNS': 5},
#   '<START>NNS<SEP>with<END>': {'IN': 960},
#   '<START>IN<SEP>such<END>': {'JJ': 69, 'PDT': 12},
#   '<START>JJ<SEP>slogans<END>': {'NNS': 16},
#   '<START>NNS<SEP>as<END>': {'IN': 391, 'RB': 46},
#   '<START>IN<SEP>"<END>': {'``': 227},
#   '<START>``<SEP>Bush<END>': {'NNP': 1},
#   '<START>NNP<SEP>Number<END>': {'NN': 1},
#   '<START>NN<SEP>One<END>': {'CD': 2},
#   '<START>CD<SEP>Terrorist<END>': {'NN': 1},
#   '<START>NN<SEP>"<END>': {'``': 485},
#   '<START>``<SEP>and<END>': {'CC': 107},
#   '<START>CC<SEP>"<END>': {'``': 38},
#   '<START>``<SEP>Stop<END>': {'VB': 1, 'NNP': 1},
#   '<START>DT<SEP>Bombings<END>': {'NNS': 1},
#   '<START>NNS<SEP>.<END>': {'.': 10363},
#   '<START>.<SEP>"<END>': {'``': 698},
#   '<START>PRP<SEP>marched<END>': {'VBD': 5},
#   '<START>VBD<SEP>from<END>': {'IN': 205},
#   '<START>DT<SEP>Houses<END>': {'NNS': 1},
#   '<START>IN<SEP>Parliament<END>': {'NN': 1, 'NNP': 7},
#   '<START>NN<SEP>to<END>': {'TO': 5697, 'IN': 34, 'CC': 2},
#   '<START>TO<SEP>a<END>': {'DT': 615},
#   '<START>DT<SEP>rally<END>': {'NN': 44},
#   '<START>IN<SEP>Hyde<END>': {'NNP': 1},
#   '<START>NNP<SEP>Park<END>': {'NNP': 18},
#   '<START>NNP<SEP>.<END>': {'.': 10505},
#   '<START>NNS<SEP>put<END>': {'VBD': 19, 'VBN': 6, 'VBP': 3},
#   '<START>DT<SEP>number<END>': {'NN': 308},
#   '<START>IN<SEP>marchers<END>': {'NNS': 2},
#   '<START>NNS<SEP>at<END>': {'IN': 614},
#   '<START>IN<SEP>10000<END>': {'CD': 34},
#   '<START>CD<SEP>while<END>': {'IN': 17},
#   '<START>IN<SEP>organizers<END>': {'NNS': 4},
#   '<START>NNS<SEP>claimed<END>': {'VBD': 16, 'VBN': 1},
#   '<START>VBD<SEP>it<END>': {'PRP': 449},
#   '<START>PRP<SEP>was<END>': {'VBD': 782},
#   '<START>VBD<SEP>1,00,000<END>': {'CD': 1},
#   '<START>CD<SEP>.<END>': {'.': 2316},
#   '<START>DT<SEP>protest<END>': {'NN': 60},
#   '<START>NN<SEP>comes<END>': {'VBZ': 182},
#   '<START>VBZ<SEP>on<END>': {'IN': 178},
#   '<START>DT<SEP>eve<END>': {'NN': 22},
#   '<START>DT<SEP>annual<END>': {'JJ': 50},
#   '<START>JJ<SEP>conference<END>': {'NN': 44},
#   '<START>IN<SEP>Britain<END>': {'NNP': 122},
#   "<START>NNP<SEP>'s<END>": {'POS': 7728, 'NNP': 2},
#   '<START>POS<SEP>ruling<END>': {'VBG': 15, 'NN': 41},
#   '<START>VBG<SEP>Labor<END>': {'NNP': 1},
#   '<START>NNP<SEP>Party<END>': {'NNP': 248},
#   '<START>NNP<SEP>in<END>': {'IN': 2501},
#   '<START>DT<SEP>southern<END>': {'JJ': 257},
#   '<START>JJ<SEP>English<END>': {'JJ': 2},
#   '<START>JJ<SEP>seaside<END>': {'NN': 3},
#   '<START>NN<SEP>resort<END>': {'NN': 11},
#   '<START>IN<SEP>Brighton<END>': {'NNP': 1},
#   '<START>DT<SEP>party<END>': {'NN': 75},
#   '<START>NN<SEP>is<END>': {'VBZ': 2311},
#   '<START>VBZ<SEP>divided<END>': {'VBN': 15},
#   '<START>VBN<SEP>over<END>': {'IN': 88, 'RP': 30},
#   '<START>POS<SEP>participation<END>': {'NN': 8},
#   '<START>DT<SEP>Iraq<END>': {'NNP': 42},
#   '<START>NNP<SEP>conflict<END>': {'NN': 9},
#   '<START>NN<SEP>and<END>': {'CC': 5086},
#   '<START>CC<SEP>the<END>': {'DT': 1667},
#   '<START>DT<SEP>continued<END>': {'JJ': 16, 'VBN': 1, 'VBD': 1},
#   '<START>JJ<SEP>deployment<END>': {'NN': 7},
#   '<START>IN<SEP>8500<END>': {'CD': 2},
#   '<START>CD<SEP>British<END>': {'JJ': 38, 'NN': 1, 'NNP': 1},
#   '<START>NNS<SEP>in<END>': {'IN': 6115},
#   '<START>DT<SEP>London<END>': {'NNP': 39},
#   '<START>NNP<SEP>march<END>': {'NN': 2},
#   '<START>NN<SEP>came<END>': {'VBD': 190},
#   '<START>VBD<SEP>ahead<END>': {'RB': 4},
#   '<START>RB<SEP>of<END>': {'IN': 374},
#   '<START>IN<SEP>anti-war<END>': {'JJ': 7},
#   '<START>JJ<SEP>protests<END>': {'NNS': 117},
#   '<START>NNS<SEP>today<END>': {'NN': 24},
#   '<START>IN<SEP>other<END>': {'JJ': 281},
#   '<START>JJ<SEP>cities<END>': {'NNS': 88},
#   '<START>NNS<SEP>,<END>': {',': 4829},
#   '<START>,<SEP>including<END>': {'VBG': 708, 'IN': 2},
#   '<START>VBG<SEP>Rome<END>': {'NNP': 1},
#   '<START>NNP<SEP>,<END>': {',': 11543, 'CC': 1},
#   '<START>,<SEP>Paris<END>': {'NNP': 4},
#   '<START>,<SEP>and<END>': {'CC': 2557},
#   '<START>CC<SEP>Madrid<END>': {'NNP': 2},
#   '<START>DT<SEP>International<END>': {'NNP': 225, 'JJ': 1},
#   '<START>NNP<SEP>Atomic<END>': {'NNP': 85},
#   '<START>NNP<SEP>Energy<END>': {'NNP': 117},
#   '<START>NNP<SEP>Agency<END>': {'NNP': 214},
#   '<START>NNP<SEP>is<END>': {'VBZ': 1954},
#   '<START>VBZ<SEP>to<END>': {'TO': 916, 'IN': 3},
#   '<START>TO<SEP>hold<END>': {'VB': 126},
#   '<START>VB<SEP>second<END>': {'JJ': 3},
#   '<START>JJ<SEP>day<END>': {'NN': 141},
#   '<START>IN<SEP>talks<END>': {'NNS': 229},
#   '<START>IN<SEP>Vienna<END>': {'NNP': 50},
#   '<START>NNP<SEP>Wednesday<END>': {'NNP': 176},
#   '<START>NNP<SEP>on<END>': {'IN': 647},
#   '<START>IN<SEP>how<END>': {'WRB': 77},
#   '<START>WRB<SEP>to<END>': {'TO': 61},
#   '<START>TO<SEP>respond<END>': {'VB': 25},
#   '<START>VB<SEP>to<END>': {'TO': 852, 'IN': 12},
#   '<START>TO<SEP>Iran<END>': {'NNP': 53},
#   '<START>POS<SEP>resumption<END>': {'NN': 2},
#   '<START>IN<SEP>low-level<END>': {'JJ': 2},
#   '<START>JJ<SEP>uranium<END>': {'NN': 22},
#   '<START>NN<SEP>conversion<END>': {'NN': 15},
#   '<START>NNP<SEP>this<END>': {'DT': 93},
#   '<START>DT<SEP>week<END>': {'NN': 541},
#   '<START>NN<SEP>restarted<END>': {'VBD': 1},
#   '<START>VBD<SEP>parts<END>': {'NNS': 8},
#   '<START>DT<SEP>conversion<END>': {'NN': 4},
#   '<START>NN<SEP>process<END>': {'NN': 138},
#   '<START>NN<SEP>at<END>': {'IN': 869},
#   '<START>IN<SEP>its<END>': {'PRP$': 1100},
#   '<START>PRP$<SEP>Isfahan<END>': {'NNP': 3},
#   '<START>NNP<SEP>nuclear<END>': {'JJ': 52},
#   '<START>JJ<SEP>plant<END>': {'NN': 18},
#   '<START>JJ<SEP>officials<END>': {'NNS': 1161},
#   '<START>NNS<SEP>say<END>': {'VBP': 3181},
#   '<START>VBP<SEP>they<END>': {'PRP': 491},
#   '<START>PRP<SEP>expect<END>': {'VBP': 24, 'VB': 1},
#   '<START>VBP<SEP>to<END>': {'TO': 440, 'IN': 5},
#   '<START>TO<SEP>get<END>': {'VB': 96},
#   '<START>VB<SEP>access<END>': {'NN': 14},
#   '<START>TO<SEP>sealed<END>': {'JJ': 1},
#   '<START>JJ<SEP>sensitive<END>': {'JJ': 2},
#   '<START>JJ<SEP>parts<END>': {'NNS': 74},
#   '<START>DT<SEP>plant<END>': {'NN': 23},
#   '<START>NN<SEP>Wednesday<END>': {'NNP': 249},
#   '<START>,<SEP>after<END>': {'IN': 278},
#   '<START>IN<SEP>an<END>': {'DT': 1671},
#   '<START>DT<SEP>IAEA<END>': {'NNP': 46},
#   '<START>NNP<SEP>surveillance<END>': {'NN': 3},
#   '<START>NN<SEP>system<END>': {'NN': 132},
#   '<START>NN<SEP>begins<END>': {'VBZ': 21},
#   '<START>VBZ<SEP>functioning<END>': {'VBG': 2},
#   '<START>VBG<SEP>.<END>': {'.': 216},
#   '<START>DT<SEP>step<END>': {'NN': 20},
#   '<START>NN<SEP>will<END>': {'MD': 842, 'NN': 1},
#   '<START>MD<SEP>allow<END>': {'VB': 66},
#   '<START>DT<SEP>facility<END>': {'NN': 32},
#   '<START>TO<SEP>operate<END>': {'VB': 15},
#   '<START>VB<SEP>at<END>': {'IN': 109},
#   '<START>IN<SEP>full<END>': {'JJ': 16},
#   '<START>JJ<SEP>capacity<END>': {'NN': 14},
#   '<START>DT<SEP>European<END>': {'NNP': 293, 'JJ': 70},
#   '<START>NNP<SEP>Union<END>': {'NNP': 562},
#   '<START>,<SEP>with<END>': {'IN': 326},
#   '<START>IN<SEP>U.S.<END>': {'NNP': 510},
#   '<START>NNP<SEP>backing<END>': {'NN': 4, 'VBG': 1},
#   '<START>NN<SEP>,<END>': {',': 10752},
#   '<START>,<SEP>has<END>': {'VBZ': 287},
#   '<START>VBZ<SEP>threatened<END>': {'VBN': 38},
#   '<START>VBN<SEP>to<END>': {'TO': 3471, 'IN': 24},
#   '<START>TO<SEP>refer<END>': {'VB': 17},
#   '<START>VB<SEP>Iran<END>': {'NNP': 88},
#   '<START>TO<SEP>the<END>': {'DT': 2166},
#   '<START>DT<SEP>U.N.<END>': {'NNP': 490},
#   '<START>NNP<SEP>Security<END>': {'NNP': 304, 'NN': 1},
#   '<START>NNP<SEP>Council<END>': {'NNP': 355},
#   '<START>,<SEP>which<END>': {'WDT': 1208, 'WP': 1},
#   '<START>WDT<SEP>could<END>': {'MD': 86},
#   '<START>MD<SEP>impose<END>': {'VB': 8},
#   '<START>VB<SEP>sanctions<END>': {'NNS': 27},
#   '<START>NNS<SEP>if<END>': {'IN': 71},
#   '<START>IN<SEP>it<END>': {'PRP': 621},
#   '<START>PRP<SEP>finds<END>': {'VBZ': 6},
#   '<START>VBZ<SEP>Tehran<END>': {'NNP': 22},
#   '<START>NNP<SEP>has<END>': {'VBZ': 3147},
#   '<START>VBZ<SEP>violated<END>': {'VBN': 3},
#   '<START>VBN<SEP>the<END>': {'DT': 1316},
#   '<START>DT<SEP>Nuclear<END>': {'NNP': 17},
#   '<START>NNP<SEP>Non-Proliferation<END>': {'NNP': 18},
#   '<START>NNP<SEP>treaty<END>': {'NN': 11},
#   '<START>POS<SEP>new<END>': {'JJ': 93},
#   '<START>JJ<SEP>President<END>': {'NNP': 917, 'NN': 2},
#   '<START>NNP<SEP>Mahmoud<END>': {'NNP': 167},
#   '<START>NNP<SEP>Ahmadinejad<END>': {'NNP': 136},
#   '<START>NNP<SEP>said<END>': {'VBD': 1791, 'VBN': 1},
#   '<START>VBD<SEP>Tuesday<END>': {'NNP': 217},
#   '<START>NNP<SEP>that<END>': {'IN': 766, 'DT': 1, 'WDT': 172},
#   '<START>IN<SEP>European<END>': {'JJ': 59, 'NNP': 26},
#   '<START>JJ<SEP>incentives<END>': {'NNS': 28},
#   '<START>NNS<SEP>aimed<END>': {'VBN': 53},
#   '<START>VBN<SEP>at<END>': {'IN': 816},
#   '<START>IN<SEP>persuading<END>': {'VBG': 7},
#   '<START>VBG<SEP>Iran<END>': {'NNP': 46},
#   '<START>TO<SEP>end<END>': {'VB': 135},
#   '<START>VB<SEP>its<END>': {'PRP$': 482},
#   '<START>PRP$<SEP>nuclear<END>': {'JJ': 196},
#   '<START>JJ<SEP>fuel<END>': {'NN': 80},
#   '<START>NN<SEP>program<END>': {'NN': 161},
#   '<START>NN<SEP>are<END>': {'VBP': 306},
#   '<START>VBP<SEP>an<END>': {'DT': 113},
#   '<START>DT<SEP>insult<END>': {'NN': 3},
#   '<START>DT<SEP>Iranian<END>': {'JJ': 112, 'NN': 1},
#   '<START>JJ<SEP>nation<END>': {'NN': 107},
#   '<START>CD<SEP>Germans<END>': {'NNS': 7},
#   '<START>NNS<SEP>and<END>': {'CC': 4271},
#   '<START>CC<SEP>four<END>': {'CD': 69},
#   '<START>CD<SEP>Nigerian<END>': {'JJ': 3, 'NN': 1},
#   '<START>JJ<SEP>oil<END>': {'NN': 368},
#   '<START>NN<SEP>workers<END>': {'NNS': 190},
#   '<START>NNS<SEP>were<END>': {'VBD': 2190},
#   '<START>VBD<SEP>kidnapped<END>': {'VBN': 68},
#   '<START>VBN<SEP>by<END>': {'IN': 2377},
#   '<START>IN<SEP>armed<END>': {'JJ': 35},
#   '<START>JJ<SEP>militants<END>': {'NNS': 286},
#   '<START>NNS<SEP>during<END>': {'IN': 259},
#   '<START>IN<SEP>a<END>': {'DT': 8651},
#   '<START>DT<SEP>raid<END>': {'NN': 84},
#   '<START>NN<SEP>on<END>': {'IN': 2174},
#   '<START>DT<SEP>boat<END>': {'NN': 28},
#   '<START>IN<SEP>Nigeria<END>': {'NNP': 85},
#   '<START>POS<SEP>southern<END>': {'JJ': 38},
#   '<START>JJ<SEP>oil-rich<END>': {'JJ': 2},
#   '<START>JJ<SEP>Delta<END>': {'NNP': 1},
#   '<START>NNP<SEP>region<END>': {'NN': 235},
#   '<START>DT<SEP>official<END>': {'NN': 79, 'JJ': 130},
#   '<START>NN<SEP>with<END>': {'IN': 1598},
#   '<START>DT<SEP>German<END>': {'JJ': 64, 'NN': 3},
#   '<START>JJ<SEP>firm<END>': {'NN': 17},
#   '<START>NN<SEP>Bilfinger<END>': {'NNP': 3},
#   '<START>NNP<SEP>Berger<END>': {'NNP': 5},
#   '<START>,<SEP>Thomas<END>': {'NNP': 4},
#   '<START>NNP<SEP>Horbach<END>': {'NNP': 1},
#   '<START>,<SEP>said<END>': {'VBD': 289, 'VBN': 1},
#   '<START>DT<SEP>gunmen<END>': {'NNS': 29},
#   '<START>NNS<SEP>stopped<END>': {'VBD': 12},
#   '<START>DT<SEP>supply<END>': {'NN': 5},
#   '<START>NN<SEP>boat<END>': {'NN': 14},
#   '<START>NNP<SEP>as<END>': {'IN': 557, 'RB': 29},
#   '<START>PRP<SEP>sailed<END>': {'VBD': 4},
#   '<START>IN<SEP>Delta<END>': {'NNP': 2},
#   '<START>NNP<SEP>State<END>': {'NNP': 106},
#   '<START>TO<SEP>Bayelsa<END>': {'NNP': 1},
#   '<START>TO<SEP>inspect<END>': {'VB': 12},
#   '<START>VB<SEP>an<END>': {'DT': 308},
#   '<START>DT<SEP>offshore<END>': {'JJ': 11},
#   '<START>NN<SEP>field<END>': {'NN': 19},
#   '<START>NN<SEP>owned<END>': {'VBN': 11},
#   '<START>IN<SEP>Royal-Dutch<END>': {'NNP': 2},
#   '<START>NNP<SEP>Shell<END>': {'NNP': 10},
#   '<START>NN<SEP>works<END>': {'VBZ': 10},
#   '<START>VBZ<SEP>as<END>': {'IN': 89, 'RB': 6},
#   '<START>DT<SEP>sub-contractor<END>': {'NN': 1},
#   '<START>NN<SEP>for<END>': {'IN': 3290},
#   '<START>IN<SEP>Shell<END>': {'NNP': 2},
#   '<START>JJ<SEP>groups<END>': {'NNS': 211},
#   '<START>NNS<SEP>frequently<END>': {'RB': 10},
#   '<START>RB<SEP>attack<END>': {'VBP': 6, 'NN': 1, 'VB': 1},
#   '<START>VBP<SEP>oil<END>': {'NN': 8},
#   '<START>NN<SEP>operations<END>': {'NNS': 71},
#   '<START>DT<SEP>Niger<END>': {'NNP': 24},
#   '<START>NNP<SEP>Delta<END>': {'NNP': 36},
#   '<START>TO<SEP>demand<END>': {'VB': 41},
#   '<START>VB<SEP>social<END>': {'JJ': 5},
#   '<START>JJ<SEP>services<END>': {'NNS': 54},
#   '<START>CC<SEP>better<END>': {'JJR': 10, 'RBR': 1},
#   '<START>JJR<SEP>job<END>': {'NN': 5},
#   '<START>NN<SEP>opportunities<END>': {'NNS': 12},
#   '<START>IN<SEP>multinational<END>': {'JJ': 4},
#   '<START>JJ<SEP>companies<END>': {'NNS': 67},
#   '<START>JJ<SEP>residents<END>': {'NNS': 40},
#   '<START>NNS<SEP>often<END>': {'RB': 24},
#   '<START>RB<SEP>complain<END>': {'VBP': 2},
#   '<START>PRP<SEP>have<END>': {'VBP': 266},
#   '<START>VBP<SEP>been<END>': {'VBN': 1163},
#   '<START>VBN<SEP>cheated<END>': {'VBN': 1},
#   '<START>VBN<SEP>out<END>': {'IN': 63, 'RP': 190},
#   '<START>IN<SEP>of<END>': {'IN': 679},
#   '<START>DT<SEP>huge<END>': {'JJ': 51},
#   '<START>JJ<SEP>riches<END>': {'NNS': 1},
#   '<START>NNS<SEP>extracted<END>': {'VBN': 3},
#   '<START>VBN<SEP>from<END>': {'IN': 416},
#   '<START>IN<SEP>their<END>': {'PRP$': 710},
#   '<START>PRP$<SEP>tribal<END>': {'JJ': 4},
#   '<START>JJ<SEP>lands<END>': {'NNS': 11},
#   '<START>NNS<SEP>-<END>': {':': 120, 'IN': 130, 'LRB': 1, 'RRB': 1, ',': 1},
#   '<START>:<SEP>where<END>': {'WRB': 4},
#   '<START>WRB<SEP>the<END>': {'DT': 384},
#   '<START>DT<SEP>bulk<END>': {'NN': 14},
#   '<START>POS<SEP>2.3<END>': {'CD': 1},
#   '<START>CD<SEP>million<END>': {'CD': 852},
#   '<START>CD<SEP>barrels<END>': {'NNS': 80},
#   '<START>IN<SEP>petroleum<END>': {'NN': 9},
#   '<START>VBP<SEP>pumped<END>': {'VBN': 1},
#   '<START>VBN<SEP>daily<END>': {'RB': 3},
#   '<START>RB<SEP>.<END>': {'.': 921},
#   '<START>JJ<SEP>Islamist<END>': {'JJ': 1, 'NNP': 10, 'NN': 14},
#   '<START>JJ<SEP>rebels<END>': {'NNS': 167},
#   '<START>VBP<SEP>fired<END>': {'VBN': 10},
#   '<START>VBN<SEP>mortar<END>': {'NN': 1},
#   '<START>NN<SEP>shells<END>': {'NNS': 12},
#   '<START>DT<SEP>palace<END>': {'NN': 4},
#   '<START>NN<SEP>used<END>': {'VBN': 32, 'VBD': 16},
#   '<START>IN<SEP>Somalia<END>': {'NNP': 153},
#   '<START>POS<SEP>interim<END>': {'JJ': 39, 'NNP': 1, 'NN': 1},
#   '<START>NNP<SEP>Abdullahi<END>': {'NNP': 10},
#   '<START>NNP<SEP>Yusuf<END>': {'NNP': 14},
#   '<START>NNP<SEP>Ahmad<END>': {'NNP': 28},
#   '<START>VBD<SEP>not<END>': {'RB': 704},
#   '<START>RB<SEP>immediately<END>': {'RB': 69},
#   '<START>RB<SEP>clear<END>': {'JJ': 124},
#   '<START>JJ<SEP>if<END>': {'IN': 68},
#   '<START>DT<SEP>president<END>': {'NN': 336},
#   '<START>NN<SEP>was<END>': {'VBD': 2018},
#   '<START>VBD<SEP>in<END>': {'IN': 1212, 'RP': 1},
#   '<START>IN<SEP>Mogadishu<END>': {'NNP': 43},
#   '<START>NNP<SEP>when<END>': {'WRB': 195},
#   '<START>DT<SEP>attack<END>': {'NN': 478},
#   '<START>NN<SEP>occurred<END>': {'VBD': 135},
#   '<START>VBD<SEP>or<END>': {'CC': 13},
#   '<START>CC<SEP>if<END>': {'IN': 12},
#   '<START>IN<SEP>anyone<END>': {'DT': 13},
#   '<START>DT<SEP>was<END>': {'VBD': 34},
#   '<START>VBD<SEP>hurt<END>': {'VBN': 33},
#   '<START>VBN<SEP>.<END>': {'.': 1479},
#   '<START>JJ<SEP>news<END>': {'NN': 237},
#   '<START>NN<SEP>reports<END>': {'NNS': 82, 'VBZ': 51, 'VBP': 2},
#   '<START>NNS<SEP>said<END>': {'VBD': 632, 'VBN': 2},
#   '<START>VBD<SEP>at<END>': {'IN': 447},
#   '<START>IN<SEP>least<END>': {'JJS': 1461, 'JJ': 7},
#   '<START>JJS<SEP>five<END>': {'CD': 62},
#   '<START>CD<SEP>mortar<END>': {'NN': 5, 'JJ': 1},
#   '<START>NNS<SEP>hit<END>': {'VBD': 41, 'VBN': 7, 'VBP': 2},
#   '<START>NN<SEP>compound<END>': {'NN': 8},
#   '<START>CC<SEP>other<END>': {'JJ': 438},
#   '<START>JJ<SEP>mortars<END>': {'NNS': 2},
#   '<START>VBD<SEP>fired<END>': {'VBN': 28},
#   '<START>VBN<SEP>elsewhere<END>': {'RB': 10},
#   '<START>RB<SEP>in<END>': {'IN': 545},
#   '<START>DT<SEP>attacks<END>': {'NNS': 158},
#   '<START>NNS<SEP>occurred<END>': {'VBD': 27},
#   '<START>VBD<SEP>after<END>': {'IN': 132},
#   '<START>DT<SEP>government<END>': {'NN': 951},
# ...
#   '<START>IN<SEP>PRP<SEP>VBZ<SEP>law<END>': {'NN': 1},
#   '<START>PRP<SEP>VBZ<SEP>NN<SEP>,<END>': {',': 5},
#   '<START>VBZ<SEP>NN<SEP>,<SEP>a<END>': {'DT': 1},
#   '<START>NN<SEP>,<SEP>DT<SEP>step<END>': {'NN': 2},
#   '<START>,<SEP>DT<SEP>NN<SEP>seen<END>': {'VBN': 2},
#   '<START>DT<SEP>NN<SEP>VBN<SEP>only<END>': {'RB': 2},
#   '<START>NN<SEP>VBN<SEP>RB<SEP>as<END>': {'IN': 1},
#   '<START>VBN<SEP>RB<SEP>IN<SEP>a<END>': {'DT': 18},
#   '<START>RB<SEP>IN<SEP>DT<SEP>formality<END>': {'NN': 1},
#   '<START>DT<SEP>JJ<SEP>NN<SEP>calls<END>': {'VBZ': 6},
#   '<START>JJ<SEP>NN<SEP>VBZ<SEP>for<END>': {'IN': 19},
#   '<START>NN<SEP>VBZ<SEP>IN<SEP>setting<END>': {'VBG': 1},
#   '<START>VBZ<SEP>IN<SEP>VBG<SEP>up<END>': {'RP': 1},
#   '<START>IN<SEP>VBG<SEP>RP<SEP>a<END>': {'DT': 11},
#   '<START>VBG<SEP>RP<SEP>DT<SEP>"<END>': {'``': 1},
#   '<START>RP<SEP>DT<SEP>``<SEP>religious<END>': {'JJ': 1},
#   '<START>DT<SEP>``<SEP>JJ<SEP>police<END>': {'NN': 1},
#   '<START>``<SEP>JJ<SEP>NN<SEP>force<END>': {'NN': 1},
#   '<START>JJ<SEP>NN<SEP>NN<SEP>"<END>': {'``': 12},
#   '<START>NN<SEP>NN<SEP>``<SEP>to<END>': {'TO': 5},
#   '<START>NN<SEP>``<SEP>TO<SEP>make<END>': {'VB': 1},
#   '<START>``<SEP>TO<SEP>VB<SEP>sure<END>': {'JJ': 1},
#   '<START>TO<SEP>VB<SEP>JJ<SEP>people<END>': {'NNS': 3},
#   '<START>VB<SEP>JJ<SEP>NNS<SEP>adhere<END>': {'VBP': 1},
#   '<START>JJ<SEP>NNS<SEP>VBP<SEP>to<END>': {'TO': 52, 'IN': 1},
#   '<START>NNS<SEP>VBP<SEP>TO<SEP>Islamic<END>': {'JJ': 1},
#   '<START>VBP<SEP>TO<SEP>JJ<SEP>values<END>': {'NNS': 1},
#   '<START>TO<SEP>JJ<SEP>NNS<SEP>in<END>': {'IN': 25},
#   '<START>JJ<SEP>NNS<SEP>IN<SEP>public<END>': {'JJ': 5},
#   '<START>NNS<SEP>IN<SEP>JJ<SEP>places<END>': {'NNS': 2},
#   '<START>JJ<SEP>NNS<SEP>,<SEP>and<END>': {'CC': 169},
#   '<START>NNS<SEP>,<SEP>CC<SEP>entertainment<END>': {'NN': 1},
#   '<START>,<SEP>CC<SEP>NN<SEP>outlets<END>': {'NNS': 1},
#   '<START>CC<SEP>NN<SEP>NNS<SEP>close<END>': {'RB': 1},
#   '<START>NN<SEP>NNS<SEP>RB<SEP>during<END>': {'IN': 2},
#   '<START>NNS<SEP>RB<SEP>IN<SEP>weekly<END>': {'JJ': 1},
#   '<START>RB<SEP>IN<SEP>JJ<SEP>Friday<END>': {'NNP': 1},
#   '<START>IN<SEP>JJ<SEP>NNP<SEP>prayers<END>': {'NNS': 1},
#   '<START>JJ<SEP>NNP<SEP>NNS<SEP>.<END>': {'.': 59},
#   '<START>NNS<SEP>MD<SEP>VB<SEP>jailed<END>': {'VBN': 1},
#   '<START>MD<SEP>VB<SEP>VBN<SEP>for<END>': {'IN': 34},
#   '<START>VB<SEP>VBN<SEP>IN<SEP>up<END>': {'RB': 2},
#   '<START>VBN<SEP>IN<SEP>RB<SEP>to<END>': {'TO': 2},
#   '<START>IN<SEP>RB<SEP>TO<SEP>six<END>': {'CD': 2},
#   '<START>RB<SEP>TO<SEP>CD<SEP>months<END>': {'NNS': 1},
#   '<START>DT<SEP>NN<SEP>VBZ<SEP>denounced<END>': {'VBN': 1},
#   '<START>NN<SEP>VBZ<SEP>VBN<SEP>the<END>': {'DT': 154},
#   '<START>VBZ<SEP>VBN<SEP>DT<SEP>measure<END>': {'NN': 2},
#   '<START>VBN<SEP>DT<SEP>NN<SEP>,<END>': {',': 60},
#   '<START>DT<SEP>NN<SEP>,<SEP>comparing<END>': {'VBG': 1},
#   '<START>NN<SEP>,<SEP>VBG<SEP>it<END>': {'PRP': 73},
#   '<START>,<SEP>VBG<SEP>PRP<SEP>to<END>': {'TO': 20},
#   '<START>VBG<SEP>PRP<SEP>TO<SEP>the<END>': {'DT': 7},
#   '<START>PRP<SEP>TO<SEP>DT<SEP>draconian<END>': {'JJ': 1},
#   '<START>TO<SEP>DT<SEP>JJ<SEP>rule<END>': {'NN': 1},
#   '<START>JJ<SEP>NN<SEP>IN<SEP>the<END>': {'DT': 2403},
#   '<START>NN<SEP>IN<SEP>DT<SEP>former<END>': {'JJ': 50},
#   '<START>IN<SEP>DT<SEP>JJ<SEP>Taleban<END>': {'NNP': 17},
#   '<START>DT<SEP>JJ<SEP>NNP<SEP>in<END>': {'IN': 29},
#   '<START>JJ<SEP>NNP<SEP>IN<SEP>neighboring<END>': {'VBG': 1},
#   '<START>NNP<SEP>IN<SEP>VBG<SEP>Afghanistan<END>': {'NNP': 3},
#   '<START>IN<SEP>VBG<SEP>NNP<SEP>.<END>': {'.': 40},
#   '<START>NNS<SEP>VBP<SEP>PRP<SEP>have<END>': {'VBP': 100},
#   '<START>VBP<SEP>PRP<SEP>VBP<SEP>arrested<END>': {'VBN': 25},
#   '<START>PRP<SEP>VBP<SEP>VBN<SEP>a<END>': {'DT': 32},
#   '<START>VBP<SEP>VBN<SEP>DT<SEP>man<END>': {'NN': 11},
#   '<START>VBN<SEP>DT<SEP>NN<SEP>who<END>': {'WP': 6},
#   '<START>DT<SEP>NN<SEP>WP<SEP>dressed<END>': {'VBD': 1},
#   '<START>NN<SEP>WP<SEP>VBD<SEP>as<END>': {'IN': 2},
#   '<START>WP<SEP>VBD<SEP>IN<SEP>suicide<END>': {'NN': 1},
#   '<START>VBD<SEP>IN<SEP>NN<SEP>bomber<END>': {'NN': 1},
#   '<START>IN<SEP>NN<SEP>NN<SEP>at<END>': {'IN': 18},
#   '<START>NN<SEP>NN<SEP>IN<SEP>a<END>': {'DT': 268},
#   '<START>NN<SEP>IN<SEP>DT<SEP>demonstration<END>': {'NN': 4},
#   '<START>IN<SEP>DT<SEP>NN<SEP>against<END>': {'IN': 59},
#   '<START>NN<SEP>IN<SEP>DT<SEP>publication<END>': {'NN': 2},
#   '<START>DT<SEP>NN<SEP>IN<SEP>cartoons<END>': {'NNS': 3},
#   '<START>NN<SEP>IN<SEP>NNS<SEP>depicting<END>': {'VBG': 1},
#   '<START>IN<SEP>NNS<SEP>VBG<SEP>Islam<END>': {'NNP': 1},
#   "<START>NNS<SEP>VBG<SEP>NNP<SEP>'s<END>": {'POS': 16},
#   '<START>VBG<SEP>NNP<SEP>POS<SEP>Prophet<END>': {'NNP': 2},
#   '<START>NNP<SEP>POS<SEP>NNP<SEP>Muhammad<END>': {'NNP': 1},
#   '<START>POS<SEP>NNP<SEP>NNP<SEP>.<END>': {'.': 50},
#   '<START>NNP<SEP>NNS<SEP>VBD<SEP>Tuesday<END>': {'NNP': 11},
#   '<START>NNS<SEP>VBD<SEP>NNP<SEP>that<END>': {'IN': 71, 'WDT': 1},
#   '<START>VBD<SEP>NNP<SEP>IN<SEP>Omar<END>': {'NNP': 1},
#   '<START>NNP<SEP>IN<SEP>NNP<SEP>Khayam<END>': {'NNP': 1},
#   '<START>IN<SEP>NNP<SEP>NNP<SEP>was<END>': {'VBD': 45},
#   '<START>NNP<SEP>NNP<SEP>VBD<SEP>arrested<END>': {'VBN': 22},
#   '<START>NNP<SEP>VBD<SEP>VBN<SEP>in<END>': {'IN': 146},
#   '<START>VBD<SEP>VBN<SEP>IN<SEP>Bedford<END>': {'NNP': 1},
#   '<START>VBN<SEP>IN<SEP>NNP<SEP>for<END>': {'IN': 46},
#   '<START>IN<SEP>NNP<SEP>IN<SEP>breaching<END>': {'VBG': 1},
#   '<START>NNP<SEP>IN<SEP>VBG<SEP>the<END>': {'DT': 95},
#   '<START>IN<SEP>VBG<SEP>DT<SEP>conditions<END>': {'NNS': 2},
#   '<START>VBG<SEP>DT<SEP>NNS<SEP>of<END>': {'IN': 62},
#   '<START>DT<SEP>NNS<SEP>IN<SEP>his<END>': {'PRP$': 24},
#   '<START>NNS<SEP>IN<SEP>PRP$<SEP>parole<END>': {'NN': 1},
#   '<START>IN<SEP>PRP$<SEP>NN<SEP>.<END>': {'.': 361},
#   '<START>NNS<SEP>VBD<SEP>DT<SEP>British<END>': {'NNP': 1, 'JJ': 3},
#   '<START>VBD<SEP>DT<SEP>NNP<SEP>Home<END>': {'NNP': 1},
#   '<START>DT<SEP>NNP<SEP>NNP<SEP>Office<END>': {'NNP': 8},
#   '<START>NNP<SEP>NNP<SEP>NNP<SEP>sought<END>': {'VBD': 3},
#   '<START>NNP<SEP>NNP<SEP>VBD<SEP>an<END>': {'DT': 51},
#   '<START>NNP<SEP>VBD<SEP>DT<SEP>investigation<END>': {'NN': 4},
#   '<START>DT<SEP>NN<SEP>IN<SEP>Khayam<END>': {'NNP': 1},
#   '<START>IN<SEP>NNP<SEP>POS<SEP>behavior<END>': {'NN': 1},
#   '<START>NNP<SEP>POS<SEP>NN<SEP>after<END>': {'IN': 4},
#   '<START>POS<SEP>NN<SEP>IN<SEP>he<END>': {'PRP': 6},
#   '<START>NN<SEP>IN<SEP>PRP<SEP>was<END>': {'VBD': 50},
#   '<START>IN<SEP>PRP<SEP>VBD<SEP>photographed<END>': {'VBN': 1},
#   '<START>PRP<SEP>VBD<SEP>VBN<SEP>last<END>': {'JJ': 12},
#   '<START>VBD<SEP>VBN<SEP>JJ<SEP>week<END>': {'NN': 24},
#   '<START>VBN<SEP>JJ<SEP>NN<SEP>at<END>': {'IN': 3},
#   '<START>JJ<SEP>NN<SEP>IN<SEP>a<END>': {'DT': 453},
#   '<START>IN<SEP>DT<SEP>NN<SEP>dressed<END>': {'VBN': 1},
#   '<START>DT<SEP>NN<SEP>VBN<SEP>in<END>': {'IN': 57, 'RP': 1},
#   '<START>NN<SEP>VBN<SEP>IN<SEP>fatigues<END>': {'NNS': 1},
#   '<START>VBN<SEP>IN<SEP>NNS<SEP>,<END>': {',': 39},
#   '<START>IN<SEP>NNS<SEP>,<SEP>a<END>': {'DT': 7},
#   '<START>NNS<SEP>,<SEP>DT<SEP>black<END>': {'JJ': 1},
#   '<START>,<SEP>DT<SEP>JJ<SEP>cap<END>': {'NN': 1},
#   '<START>JJ<SEP>NN<SEP>,<SEP>and<END>': {'CC': 247},
#   '<START>NN<SEP>,<SEP>CC<SEP>a<END>': {'DT': 45},
#   '<START>,<SEP>CC<SEP>DT<SEP>bulky<END>': {'JJ': 1},
#   '<START>CC<SEP>DT<SEP>JJ<SEP>belt<END>': {'NN': 1},
#   '<START>DT<SEP>NNP<SEP>NNP<SEP>spokesman<END>': {'NN': 55},
#   '<START>NNP<SEP>NNP<SEP>NN<SEP>told<END>': {'VBD': 3},
#   '<START>NNP<SEP>NN<SEP>VBD<SEP>the<END>': {'DT': 110},
#   '<START>NN<SEP>VBD<SEP>DT<SEP>Associated<END>': {'NNP': 5},
#   '<START>VBD<SEP>DT<SEP>NNP<SEP>Press<END>': {'NNP': 22},
#   '<START>DT<SEP>NNP<SEP>NNP<SEP>that<END>': {'IN': 24, 'WDT': 8},
#   '<START>NNP<SEP>NNP<SEP>IN<SEP>if<END>': {'IN': 1},
#   '<START>NNP<SEP>IN<SEP>IN<SEP>the<END>': {'DT': 20},
#   '<START>IN<SEP>IN<SEP>DT<SEP>behavior<END>': {'NN': 1},
#   '<START>NN<SEP>IN<SEP>DT<SEP>paroled<END>': {'JJ': 1},
#   '<START>IN<SEP>DT<SEP>JJ<SEP>offender<END>': {'NN': 1},
#   '<START>DT<SEP>JJ<SEP>NN<SEP>gives<END>': {'VBZ': 1},
#   '<START>JJ<SEP>NN<SEP>VBZ<SEP>cause<END>': {'NN': 1},
#   '<START>NN<SEP>VBZ<SEP>NN<SEP>for<END>': {'IN': 5},
#   '<START>VBZ<SEP>NN<SEP>IN<SEP>concern<END>': {'NN': 1},
#   '<START>NN<SEP>IN<SEP>NN<SEP>,<END>': {',': 272},
#   '<START>IN<SEP>NN<SEP>,<SEP>he<END>': {'PRP': 8},
#   '<START>NN<SEP>,<SEP>PRP<SEP>can<END>': {'MD': 3},
#   '<START>,<SEP>PRP<SEP>MD<SEP>be<END>': {'VB': 14},
#   '<START>PRP<SEP>MD<SEP>VB<SEP>sent<END>': {'VBN': 2},
#   '<START>MD<SEP>VB<SEP>VBN<SEP>back<END>': {'RB': 4},
#   '<START>VB<SEP>VBN<SEP>RB<SEP>to<END>': {'TO': 9},
#   '<START>VBN<SEP>RB<SEP>TO<SEP>prison<END>': {'NN': 1},
#   '<START>RB<SEP>TO<SEP>NN<SEP>.<END>': {'.': 5},
#   '<START>DT<SEP>NNP<SEP>RB<SEP>reports<END>': {'VBZ': 2},
#   '<START>NNP<SEP>RB<SEP>VBZ<SEP>Khayam<END>': {'NNP': 1},
#   '<START>RB<SEP>VBZ<SEP>NNP<SEP>has<END>': {'VBZ': 4},
#   '<START>VBZ<SEP>NNP<SEP>VBZ<SEP>been<END>': {'VBN': 4},
#   '<START>NNP<SEP>VBZ<SEP>VBN<SEP>on<END>': {'IN': 50},
#   '<START>VBZ<SEP>VBN<SEP>IN<SEP>parole<END>': {'NN': 1},
#   '<START>VBN<SEP>IN<SEP>NN<SEP>from<END>': {'IN': 8},
#   '<START>IN<SEP>NN<SEP>IN<SEP>prison<END>': {'NN': 5},
#   '<START>NN<SEP>IN<SEP>NN<SEP>since<END>': {'IN': 15},
#   '<START>IN<SEP>NN<SEP>IN<SEP>last<END>': {'JJ': 10},
#   '<START>NN<SEP>IN<SEP>JJ<SEP>year<END>': {'NN': 38},
#   '<START>IN<SEP>JJ<SEP>NN<SEP>after<END>': {'IN': 15},
#   '<START>JJ<SEP>NN<SEP>IN<SEP>serving<END>': {'VBG': 2},
#   '<START>NN<SEP>IN<SEP>VBG<SEP>half<END>': {'PDT': 1},
#   '<START>IN<SEP>VBG<SEP>PDT<SEP>his<END>': {'PRP$': 1},
#   '<START>VBG<SEP>PDT<SEP>PRP$<SEP>six-year<END>': {'JJ': 1},
#   '<START>PDT<SEP>PRP$<SEP>JJ<SEP>sentence<END>': {'NN': 1},
#   '<START>PRP$<SEP>JJ<SEP>NN<SEP>for<END>': {'IN': 25},
#   '<START>JJ<SEP>NN<SEP>IN<SEP>drug<END>': {'NN': 3},
#   '<START>NN<SEP>IN<SEP>NN<SEP>dealing<END>': {'NN': 1},
#   '<START>IN<SEP>NN<SEP>NN<SEP>.<END>': {'.': 291},
#   '<START>JJ<SEP>NNS<SEP>VBP<SEP>unidentified<END>': {'JJ': 6},
#   '<START>NNS<SEP>VBP<SEP>JJ<SEP>gunmen<END>': {'NNS': 14},
#   '<START>VBP<SEP>JJ<SEP>NNS<SEP>have<END>': {'VBP': 37},
#   '<START>JJ<SEP>NNS<SEP>VBP<SEP>killed<END>': {'VBN': 42},
#   '<START>NNS<SEP>VBP<SEP>VBN<SEP>three<END>': {'CD': 23},
#   '<START>VBP<SEP>VBN<SEP>CD<SEP>people<END>': {'NNS': 29},
#   '<START>VBN<SEP>CD<SEP>NNS<SEP>,<END>': {',': 31},
#   '<START>CD<SEP>NNS<SEP>,<SEP>including<END>': {'VBG': 148, 'IN': 1},
#   '<START>NNS<SEP>,<SEP>VBG<SEP>a<END>': {'DT': 92},
#   '<START>,<SEP>VBG<SEP>DT<SEP>former<END>': {'JJ': 5},
#   '<START>VBG<SEP>DT<SEP>JJ<SEP>government<END>': {'NN': 32},
#   '<START>DT<SEP>JJ<SEP>NN<SEP>minister<END>': {'NN': 15},
#   '<START>JJ<SEP>NN<SEP>NN<SEP>,<END>': {',': 468},
#   '<START>NN<SEP>NN<SEP>,<SEP>in<END>': {'IN': 9},
#   '<START>NN<SEP>,<SEP>IN<SEP>a<END>': {'DT': 56},
#   '<START>,<SEP>IN<SEP>DT<SEP>semi-autonomous<END>': {'JJ': 2},
#   '<START>IN<SEP>DT<SEP>JJ<SEP>tribal<END>': {'JJ': 14},
#   '<START>DT<SEP>JJ<SEP>JJ<SEP>region<END>': {'NN': 25},
#   '<START>JJ<SEP>JJ<SEP>NN<SEP>bordering<END>': {'VBG': 7},
#   '<START>JJ<SEP>NN<SEP>VBG<SEP>Afghanistan<END>': {'NNP': 11},
#   '<START>NN<SEP>VBG<SEP>NNP<SEP>.<END>': {'.': 17},
#   '<START>DT<SEP>NNS<SEP>VBP<SEP>prominent<END>': {'JJ': 1},
#   '<START>NNS<SEP>VBP<SEP>JJ<SEP>tribal<END>': {'JJ': 1},
#   '<START>VBP<SEP>JJ<SEP>JJ<SEP>leader<END>': {'NN': 2},
#   '<START>JJ<SEP>JJ<SEP>NN<SEP>Malik<END>': {'NNP': 1},
#   '<START>JJ<SEP>NN<SEP>NNP<SEP>Faridullah<END>': {'NNP': 1},
#   '<START>NN<SEP>NNP<SEP>NNP<SEP>Khan<END>': {'NNP': 6},
#   '<START>NNP<SEP>NNP<SEP>NNP<SEP>was<END>': {'VBD': 131},
#   '<START>NNP<SEP>NNP<SEP>VBD<SEP>traveling<END>': {'VBG': 2},
#   '<START>NNP<SEP>VBD<SEP>VBG<SEP>in<END>': {'IN': 6},
#   '<START>VBD<SEP>VBG<SEP>IN<SEP>South<END>': {'NNP': 1},
#   '<START>VBG<SEP>IN<SEP>NNP<SEP>Waziristan<END>': {'NNP': 1},
#   '<START>IN<SEP>NNP<SEP>NNP<SEP>Sunday<END>': {'NNP': 7},
#   '<START>NNP<SEP>NNP<SEP>NNP<SEP>when<END>': {'WRB': 8},
#   '<START>NNP<SEP>NNP<SEP>WRB<SEP>his<END>': {'PRP$': 1},
#   '<START>NNP<SEP>WRB<SEP>PRP$<SEP>vehicle<END>': {'NN': 9},
#   '<START>WRB<SEP>PRP$<SEP>NN<SEP>was<END>': {'VBD': 9},
#   '<START>PRP$<SEP>NN<SEP>VBD<SEP>ambushed<END>': {'VBN': 2},
#   '<START>NN<SEP>VBD<SEP>VBN<SEP>in<END>': {'IN': 261},
#   '<START>VBD<SEP>VBN<SEP>IN<SEP>the<END>': {'DT': 635},
#   '<START>VBN<SEP>IN<SEP>DT<SEP>Kani<END>': {'NNP': 1},
#   '<START>IN<SEP>DT<SEP>NNP<SEP>Wam<END>': {'NNP': 1},
#   '<START>DT<SEP>NNP<SEP>NNP<SEP>area<END>': {'NN': 12},
#   '<START>PRP$<SEP>NN<SEP>CC<SEP>a<END>': {'DT': 6},
#   '<START>NN<SEP>CC<SEP>DT<SEP>tribal<END>': {'JJ': 1},
#   '<START>CC<SEP>DT<SEP>JJ<SEP>elder<END>': {'NN': 1},
#   '<START>DT<SEP>JJ<SEP>NN<SEP>were<END>': {'VBD': 26},
#   '<START>JJ<SEP>NN<SEP>VBD<SEP>also<END>': {'RB': 7},
#   '<START>NN<SEP>VBD<SEP>RB<SEP>killed<END>': {'VBN': 14},
#   '<START>VBD<SEP>RB<SEP>VBN<SEP>.<END>': {'.': 90},
#   '<START>DT<SEP>NN<SEP>VBZ<SEP>claimed<END>': {'VBN': 39},
#   '<START>NN<SEP>VBZ<SEP>VBN<SEP>responsibility<END>': {'NN': 39},
#   '<START>VBZ<SEP>VBN<SEP>NN<SEP>for<END>': {'IN': 73},
#   '<START>VBN<SEP>NN<SEP>IN<SEP>the<END>': {'DT': 187},
#   '<START>NN<SEP>IN<SEP>DT<SEP>killings<END>': {'NNS': 14},
#   '<START>IN<SEP>DT<SEP>NNS<SEP>.<END>': {'.': 549},
#   '<START>NN<SEP>VBD<SEP>DT<SEP>day<END>': {'NN': 17},
#   '<START>VBD<SEP>DT<SEP>NN<SEP>after<END>': {'IN': 59},
#   '<START>NN<SEP>IN<SEP>DT<SEP>commander<END>': {'NN': 2},
#   '<START>DT<SEP>NN<SEP>IN<SEP>Pakistani<END>': {'JJ': 12},
#   '<START>IN<SEP>JJ<SEP>NNS<SEP>said<END>': {'VBD': 7},
#   '<START>JJ<SEP>NNS<SEP>VBD<SEP>the<END>': {'DT': 215},
#   '<START>NNS<SEP>VBD<SEP>DT<SEP>army<END>': {'NN': 4},
#   '<START>VBD<SEP>DT<SEP>NN<SEP>has<END>': {'VBZ': 23},
#   '<START>DT<SEP>NN<SEP>VBZ<SEP>almost<END>': {'RB': 4},
#   '<START>NN<SEP>VBZ<SEP>RB<SEP>completely<END>': {'RB': 3},
#   '<START>VBZ<SEP>RB<SEP>RB<SEP>eliminated<END>': {'VBN': 1},
#   '<START>RB<SEP>RB<SEP>VBN<SEP>militants<END>': {'NNS': 1},
#   '<START>RB<SEP>VBN<SEP>NNS<SEP>in<END>': {'IN': 10},
#   '<START>VBN<SEP>NNS<SEP>IN<SEP>South<END>': {'NNP': 1, 'JJ': 1},
#   '<START>NNS<SEP>IN<SEP>NNP<SEP>Waziristan<END>': {'NNP': 4},
#   '<START>NN<SEP>VBD<SEP>DT<SEP>refuge<END>': {'NN': 1},
#   '<START>VBD<SEP>DT<SEP>NN<SEP>for<END>': {'IN': 95},
#   '<START>DT<SEP>NN<SEP>IN<SEP>many<END>': {'JJ': 7, 'NN': 2},
#   '<START>NN<SEP>IN<SEP>JJ<SEP>al-Qaida<END>': {'NNP': 5},
#   '<START>IN<SEP>JJ<SEP>NNP<SEP>and<END>': {'CC': 54},
#   '<START>JJ<SEP>NNP<SEP>CC<SEP>Taleban<END>': {'NNP': 3},
#   '<START>NNP<SEP>CC<SEP>NNP<SEP>fighters<END>': {'NNS': 9},
#   '<START>CC<SEP>NNP<SEP>NNS<SEP>after<END>': {'IN': 1},
#   '<START>NNP<SEP>NNS<SEP>IN<SEP>the<END>': {'DT': 193},
#   '<START>NNS<SEP>IN<SEP>DT<SEP>Taleban<END>': {'NNP': 12},
#   '<START>IN<SEP>DT<SEP>NNP<SEP>government<END>': {'NN': 50},
#   '<START>DT<SEP>NNP<SEP>NN<SEP>was<END>': {'VBD': 61},
#   '<START>NNP<SEP>NN<SEP>VBD<SEP>ousted<END>': {'VBN': 4},
#   '<START>VBD<SEP>VBN<SEP>IN<SEP>Afghanistan<END>': {'NNP': 7},
#   '<START>VBN<SEP>IN<SEP>NNP<SEP>in<END>': {'IN': 59},
#   '<START>IN<SEP>NNP<SEP>IN<SEP>2001<END>': {'CD': 15},
#   '<START>NNP<SEP>IN<SEP>CD<SEP>.<END>': {'.': 253},
#   '<START>DT<SEP>JJ<SEP>JJ<SEP>military<END>': {'JJ': 10, 'NN': 3},
#   '<START>JJ<SEP>JJ<SEP>JJ<SEP>official<END>': {'NN': 8},
#   '<START>JJ<SEP>JJ<SEP>NN<SEP>says<END>': {'VBZ': 66},
#   '<START>JJ<SEP>NN<SEP>VBZ<SEP>Pakistan<END>': {'NNP': 2},
#   '<START>NN<SEP>VBZ<SEP>NNP<SEP>wants<END>': {'VBZ': 2},
#   '<START>VBZ<SEP>NNP<SEP>VBZ<SEP>to<END>': {'TO': 13},
#   '<START>NNP<SEP>VBZ<SEP>TO<SEP>put<END>': {'VB': 1},
#   '<START>VBZ<SEP>TO<SEP>VB<SEP>what<END>': {'WP': 3},
#   '<START>TO<SEP>VB<SEP>WP<SEP>he<END>': {'PRP': 16},
#   '<START>VB<SEP>WP<SEP>PRP<SEP>calls<END>': {'VBZ': 11},
#   '<START>WP<SEP>PRP<SEP>VBZ<SEP>the<END>': {'DT': 13},
#   '<START>PRP<SEP>VBZ<SEP>DT<SEP>"<END>': {'``': 21},
#   '<START>VBZ<SEP>DT<SEP>``<SEP>sordid<END>': {'JJ': 1},
#   '<START>DT<SEP>``<SEP>JJ<SEP>chapter<END>': {'NN': 1},
#   '<START>JJ<SEP>NN<SEP>``<SEP>of<END>': {'IN': 22},
#   '<START>NN<SEP>``<SEP>IN<SEP>proliferation<END>': {'NN': 1},
#   '<START>``<SEP>IN<SEP>NN<SEP>by<END>': {'IN': 1},
#   '<START>IN<SEP>NN<SEP>IN<SEP>one<END>': {'CD': 6},
#   '<START>NN<SEP>IN<SEP>CD<SEP>of<END>': {'IN': 66},
#   '<START>IN<SEP>CD<SEP>IN<SEP>its<END>': {'PRP$': 29},
#   ...}]

# %%
previously_seen
# Out:
# ['JJ', 'NNS', 'VBD', 'PRP', 'VBD', 'TO', 'DT', 'NN']

# %%
import json

# TODO: need to replace tuple keys in order to do this for output
with open('models/sentence_1.json', 'w') as json_file:
    json.dump(ngram_maps, json_file, indent=4)
